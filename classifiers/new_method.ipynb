# %%
# Parameters cell

# Model
MODEL = "davinci-002"

# Conditioners
CONDITIONERS = 1

# Sample rate
SAMPLE_SIZE = -1
SAMPLE_COUNT = -1

SAMPLE_MULTIPLIER = 1

# Corpus
CORPUS = "converted_climate_change_gpt-4-turbo-preview_gpt-4-turbo-preview_2_2"

# Narrative set
NARRATIVE_SET = "climate"

# Which helpful/unhelpful sets to use, if any
NARRATIVE_SUFFIX = ""

# The name of the experiment (i.e. where to save the results)
EXPERIMENT_NAME = "climate_synthetic_test_df"

# DEBUG = True
DEBUG = False

# %%
# # pip install
# %pip install openai dill seaborn

# %%
import os
from analyze import experiment_set, NarrativeContext

ctx = NarrativeContext(
    model=MODEL,
    conditioners=CONDITIONERS,
    # sample_rate=SAMPLE_SIZE
)

# Create the results directory
RESULTS_DIR = os.path.join("./corpus_results/new_method", EXPERIMENT_NAME)
if not os.path.exists(RESULTS_DIR):
    os.makedirs(RESULTS_DIR)

# %%
# Multiprocessing with joblib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os
import yaml
import pickle
from analyze import (
    join_many_strings,
    get_logits,
    likelihood_delta,
    stratified_n_tuple_sampling,
)
import itertools
from tqdm.auto import tqdm
from joblib import Parallel, delayed
import random


def load_experiments(name):
    path = os.path.join("../narrative_sets", name)

    with open(os.path.join(path, "helpful" + NARRATIVE_SUFFIX + ".txt"), "r") as f:
        helpful = f.read().splitlines()

    with open(os.path.join(path, "unhelpful" + NARRATIVE_SUFFIX + ".txt"), "r") as f:
        unhelpful = f.read().splitlines()

    # Neutral set might not exist, if so just use an empty list
    if not os.path.exists(os.path.join(path, "neutral" + NARRATIVE_SUFFIX + ".txt")):
        neutral = []
    else:
        with open(os.path.join(path, "neutral" + NARRATIVE_SUFFIX + ".txt"), "r") as f:
            neutral = f.read().splitlines()

    # # Drop texts less than 10 words and more than 50 words.
    # helpful = [text for text in helpful if len(text.split()) >= 10 and len(text.split()) <= 50]
    # unhelpful = [text for text in unhelpful if len(text.split()) >= 10 and len(text.split()) <= 50]
    # neutral = [text for text in neutral if len(text.split()) >= 10 and len(text.split()) <= 50]

    # Drop empty texts
    helpful = [text for text in helpful if len(text) > 0]
    unhelpful = [text for text in unhelpful if len(text) > 0]
    neutral = [text for text in neutral if len(text) > 0]

    return helpful, unhelpful, neutral


print("*** Experiment {} ***".format(NARRATIVE_SET))
helpful, unhelpful, neutral = load_experiments(NARRATIVE_SET)

print("\tHelpful: {}".format(len(helpful)))
print("\tUnhelpful: {}".format(len(unhelpful)))
print("\tNeutral: {}".format(len(neutral)))


def align_text_to_conditioners(label, narrative_sets, text, ctx, sample_size):
    # No batching
    deltas = []
    for conditioners in narrative_sets:
        conditioner_string = join_many_strings(conditioners)
        deltas.append(
            {
                "conditioners": conditioners,
                "likelihood_delta": likelihood_delta(
                    conditioner_string, text["text"], ctx
                ),
            }
        )

    return {"text": text, "likelihood_deltas": deltas}


def align(label, narrative_set, texts, sample_size):
    print("*** Aligning {} texts to {} ***".format(len(texts), label))
    results = []
    for text in tqdm(texts):
        results.append(
            align_text_to_conditioners(
                label,
                pairs[(tuple(narrative_set), text["text"])],
                text,
                ctx,
                sample_size,
            )
        )

    return results


# Load texts from corpora/{CORPUS}.json
with open(os.path.join("../corpora", f"{CORPUS}.json"), "r") as f:
    corpus_data = yaml.safe_load(f)

print("Loaded {} texts from corpus".format(len(corpus_data)))
print("Total word count:", sum([len(text["text"].split()) for text in corpus_data]))

# Use SAMPLE_COUNT
if SAMPLE_COUNT != -1 and len(corpus_data) > SAMPLE_COUNT:
    corpus_data = random.sample(corpus_data, SAMPLE_COUNT)


# Precompute narrative set -- text pairs
pairs = {}
to_precompute = set()
for narrative_set in [helpful, unhelpful, neutral]:
    for text in corpus_data:
        # # Pick a random narrative set
        # narrative_sets = list(itertools.permutations(narrative_set, CONDITIONERS))
        # narrative_sets = random.sample(narrative_sets, min(len(narrative_sets), len(narrative_set)))
        narrative_sets = []
        for _ in range(SAMPLE_MULTIPLIER):
            narrative_sets_iter = stratified_n_tuple_sampling(
                list(narrative_set), CONDITIONERS
            )
            narrative_sets.extend(narrative_sets_iter)

        # Append to the list
        pairs[(tuple(narrative_set), text["text"])] = narrative_sets

        # Add to the set of things to precompute
        for conditioners in narrative_sets:
            conditioner_string = join_many_strings(conditioners)
            to_precompute.add(join_many_strings([conditioner_string, text["text"]]))
            to_precompute.add(conditioner_string)
            to_precompute.add(text["text"])

# Get the total word count of the precompute set
print(
    "Total word count of precompute set:",
    sum([len(text.split()) for text in to_precompute]),
)
# break

# Precompute the logits
print("--- Precomputing logits ---")
get_logits(list(to_precompute), ctx.model)
print("--- Done precomputing logits ---")

# Run experiments
results = {
    "helpful": align("helpful", helpful, corpus_data, None),
    "unhelpful": align("unhelpful", unhelpful, corpus_data, None),
    # "neutral": align("neutral", neutral, corpus_data, SAMPLE_SIZE)
}

# Save results with pickle
with open(
    os.path.join(
        "corpus_results/new_method/",
        EXPERIMENT_NAME,
        f"{NARRATIVE_SET}_{CORPUS}_{MODEL}_{CONDITIONERS}_{SAMPLE_MULTIPLIER}.pkl",
    ),
    "wb",
) as f:
    pickle.dump(results, f)
# Out:
# *** Experiment climate ***
# 	Helpful: 5
# 	Unhelpful: 5
# 	Neutral: 0
# Loaded 16 texts from corpus
# Total word count: 301
# Total word count of precompute set: 7748
# --- Precomputing logits ---
#   0%|          | 0/10 [00:00<?, ?it/s]
# --- Done precomputing logits ---
# *** Aligning 16 texts to helpful ***
#   0%|          | 0/16 [00:00<?, ?it/s]
# *** Aligning 16 texts to unhelpful ***
#   0%|          | 0/16 [00:00<?, ?it/s]

# %%
import json
import yaml

# Load data from pkl
with open(
    os.path.join(
        "corpus_results/new_method/",
        EXPERIMENT_NAME,
        f"{NARRATIVE_SET}_{CORPUS}_{MODEL}_{CONDITIONERS}_{SAMPLE_MULTIPLIER}.pkl",
    ),
    "rb",
) as f:
    results = pickle.load(f)

# For each narrative set in (helpful, unhelpful), find the texts with the highest and lowest likelihood delta (relative to the other set
# of narratives) and print them.
helpful = results["helpful"]
unhelpful = results["unhelpful"]


def compute_deltas(result_set):
    # Compute generally for helpful/unhelpful/neutral
    deltas = {}
    for text in result_set:
        text_deltas = [
            delta["likelihood_delta"]["likelihood_delta"]
            for delta in text["likelihood_deltas"]
        ]
        deltas[text["text"]["text"]] = np.mean(text_deltas)
        # Get the signed max abs value
        # deltas[text["text"]["text"]] = max(text_deltas, key=abs)
        # deltas[text["text"]["text"]] = max(text_deltas)
        print(text)
    return deltas


helpful_deltas = compute_deltas(helpful)
unhelpful_deltas = compute_deltas(unhelpful)

helpful_unhelpful_diffs = []
for text in helpful:
    helpful_unhelpful_diffs.append(
        {
            "text": text["text"]["text"],
            "helpful": helpful_deltas[text["text"]["text"]],
            "unhelpful": unhelpful_deltas[text["text"]["text"]],
            # "helpful_deltas": [delta["likelihood_delta"]["likelihood_delta"] for delta in text["likelihood_deltas"]],
            # "unhelpful_deltas": [delta["likelihood_delta"]["likelihood_delta"] for delta in text["likelihood_deltas"]],
            "speaker": text["text"]["speakername"],
            "affiliation": (
                text["text"]["affiliation"] if "affiliation" in text["text"] else None
            ),
            "date": text["text"]["date"],
            "diff": helpful_deltas[text["text"]["text"]]
            - unhelpful_deltas[text["text"]["text"]],
        }
    )

helpful_unhelpful_diffs = sorted(helpful_unhelpful_diffs, key=lambda x: x["diff"])

print("Most unhelpful:")
for text in helpful_unhelpful_diffs[:10]:
    print(f"[{text['diff']}] {text['text']}")
print()
print("Most helpful:")
for text in helpful_unhelpful_diffs[-10:]:
    print(f"[{text['diff']}] {text['text']}")
print()

outpath = os.path.join(
    "corpus_results/new_method/",
    EXPERIMENT_NAME,
    f"{NARRATIVE_SET}_{CORPUS}_{MODEL}_{CONDITIONERS}_{SAMPLE_MULTIPLIER}",
)
# Save results with JSON
with open(outpath + ".json", "w") as f:
    json.dump(helpful_unhelpful_diffs, f, indent=4)

# Save in CSV format
df = pd.DataFrame(helpful_unhelpful_diffs)
df.to_csv(outpath + ".csv", index=False)
# Out:
# {'text': {'date': '2024-01-08', 'speakername': 'a', 'text': 'We must invest in solar and wind energy now to prevent catastrophic climate change impacts.'}, 'likelihood_deltas': [{'conditioners': ['An overwhelming majority of climate scientists, over 97%, agree that climate change is real and primarily caused by human activities, particularly the emission of greenhouse gases.'], 'likelihood_delta': {'p_xy': -86.85718282300002, 'p_x': -47.04408815560001, 'p_y': -45.16461943, 'likelihood_delta': 5.351524762599993}}, {'conditioners': ['Excessive concentrations of carbon dioxide in the atmosphere, while necessary for plant life, act as a potent greenhouse gas that traps heat and contributes to global warming.'], 'likelihood_delta': {'p_xy': -101.41709930699999, 'p_x': -55.799907336000004, 'p_y': -45.16461943, 'likelihood_delta': -0.4525725409999808}}, {'conditioners': ['Renewable energy technologies are advancing and becoming more efficient, offering a promising alternative to fossil fuels and a pathway to mitigating climate change.'], 'likelihood_delta': {'p_xy': -94.5306368985, 'p_x': -55.4166907629, 'p_y': -45.16461943, 'likelihood_delta': 6.050673294399992}}, {'conditioners': ['The current rapid increase in global temperatures is unprecedented and largely driven by human actions, distinguishing it from natural climate variability.'], 'likelihood_delta': {'p_xy': -105.69063304339996, 'p_x': -62.33264006719999, 'p_y': -45.16461943, 'likelihood_delta': 1.8066264538000354}}, {'conditioners': ['The impacts of climate change are global and can affect every individual through extreme weather events, health risks, and economic changes, regardless of personal experience.'], 'likelihood_delta': {'p_xy': -122.888780296, 'p_x': -81.11149204399999, 'p_y': -45.16461943, 'likelihood_delta': 3.3873311779999966}}]}
# {'text': {'date': '2024-01-08', 'speakername': 'a', 'text': 'Immediate global action is required to reduce carbon emissions and save our planet.'}, 'likelihood_deltas': [{'conditioners': ['Excessive concentrations of carbon dioxide in the atmosphere, while necessary for plant life, act as a potent greenhouse gas that traps heat and contributes to global warming.'], 'likelihood_delta': {'p_xy': -88.76051903599999, 'p_x': -55.799907336000004, 'p_y': -32.39833296, 'likelihood_delta': -0.5622787399999893}}, {'conditioners': ['Renewable energy technologies are advancing and becoming more efficient, offering a promising alternative to fossil fuels and a pathway to mitigating climate change.'], 'likelihood_delta': {'p_xy': -88.46486764850002, 'p_x': -55.4166907629, 'p_y': -32.39833296, 'likelihood_delta': -0.6498439256000239}}, {'conditioners': ['An overwhelming majority of climate scientists, over 97%, agree that climate change is real and primarily caused by human activities, particularly the emission of greenhouse gases.'], 'likelihood_delta': {'p_xy': -79.3512891924, 'p_x': -47.04408815560001, 'p_y': -32.39833296, 'likelihood_delta': 0.09113192320000252}}, {'conditioners': ['The impacts of climate change are global and can affect every individual through extreme weather events, health risks, and economic changes, regardless of personal experience.'], 'likelihood_delta': {'p_xy': -115.081159917, 'p_x': -81.11149204399999, 'p_y': -32.39833296, 'likelihood_delta': -1.5713349130000083}}, {'conditioners': ['The current rapid increase in global temperatures is unprecedented and largely driven by human actions, distinguishing it from natural climate variability.'], 'likelihood_delta': {'p_xy':
}]}
# {'text': {'date': '2024-01-08', 'speakername': 'b', 'text': 'Volcanic eruptions release far more carbon dioxide into the atmosphere than human activities ever could.'}, 'likelihood_deltas': [{'conditioners': ['The current rapid increase in global temperatures is unprecedented and largely driven by human actions, distinguishing it from natural climate variability.'], 'likelihood_delta': {'p_xy': -100.952785683377, 'p_x': -62.33264006719999, 'p_y': -33.11104018765, 'likelihood_delta': -5.509105428527015}}, {'conditioners': ['The impacts of climate change are global and can affect every individual through extreme weather events, health risks, and economic changes, regardless of personal experience.'], 'likelihood_delta': {'p_xy': -121.02570688932597, 'p_x': -81.11149204399999, 'p_y': -33.11104018765, 'likelihood_delta': -6.803174657675989}}, {'conditioners': ['Excessive concentrations of carbon dioxide in the atmosphere, while necessary for plant life, act as a potent greenhouse gas that traps heat and contributes to global warming.'], 'likelihood_delta': {'p_xy': -85.0335822559, 'p_x': -55.799907336000004, 'p_y': -33.11104018765, 'likelihood_delta': 3.877365267750001}}, {'conditioners': ['An overwhelming majority of climate scientists, over 97%, agree that climate change is real and primarily caused by human activities, particularly the emission of greenhouse gases.'], 'likelihood_delta': {'p_xy': -79.07381102379401, 'p_x': -47.04408815560001, 'p_y': -33.11104018765, 'likelihood_delta': 1.081317319455998}}, {'conditioners': ['Renewable energy technologies are advancing and becoming more efficient, offering a promising alternative to fossil fuels and a pathway to mitigating climate change.'], 'likelihood_delta': {'p_xy': -96.23038286795003, 'p_x': -55.4166907629, 'p_y': -33.11104018765, 'likelihood_delta': -7.702651917400033}}]}
# {'text': {'date': '2024-01-08', 'speakername': 'a', 'text': 'We must invest in solar and wind energy now to prevent catastrophic climate change impacts.'}, 'likelihood_deltas': [{'conditioners': ["Climate change can be seen as a part of Earth's natural cycle, and the extent to which human activities influence this process is still a subject of debate within the scientific community."], 'likelihood_delta': {'p_xy': -110.0729492258, 'p_x': -64.7372980911, 'p_y': -45.16461943, 'likelihood_delta': -0.17103170469999895}}, {'conditioners': ['Some believe that organisms have the capacity to adapt to changes in their climate, suggesting that the effects of climate change may not be as dire as often portrayed.'], 'likelihood_delta': {'p_xy': -117.14671553300005, 'p_x': -70.250260893, 'p_y': -45.16461943, 'likelihood_delta': -1.7318352100000425}}, {'conditioners': ['Despite the consensus narrative, some argue that climate change discussions are ongoing and that there is not complete agreement on the human impact.'], 'likelihood_delta': {'p_xy': -130.03861440999998, 'p_x': -82.23467644999998, 'p_y': -45.16461943, 'likelihood_delta': -2.639318529999997}}, {'conditioners': ['The occurrence of cold weather events and chilly temperatures can be used to question the assertion that there is a gradual increase in global temperatures due to human actions.'], 'likelihood_delta': {'p_xy': -139.764776014, 'p_x': -92.27123441399999, 'p_y': -45.16461943, 'likelihood_delta': -2.3289221700000127}}, {'conditioners': ['The ability of renewable energy sources to fully replace fossil fuels is contested, with skeptics questioning their efficiency and overall potential to meet global energy demands.'], 'likelihood_delta': {'p_xy': -122.5183888744, 'p_x': -78.6054044721, 'p_y': -45.16461943, 'likelihood_delta': 1.2516350277000043}}]}
# {'text': {'date': '2024-01-08', 'speakername': 'a', 'text': 'Immediate global action is required to reduce carbon emissions and save our planet.'}, 'likelihood_deltas': [{'conditioners': ['Some believe that organisms have the capacity to adapt to changes in their climate, suggesting that the effects of climate change may not be as dire as often portrayed.'], 'likelihood_delta': {'p_xy': -104.88870930300001, 'p_x': -70.250260893, 'p_y': -32.39833296, 'likelihood_delta': -2.2401154500000118}}, {'conditioners': ['Despite the consensus narrative, some argue that climate change discussions are ongoing and that there is not complete agreement on the human impact.'], 'likelihood_delta': {'p_xy': -118.76280448, 'p_x': -82.23467644999998, 'p_y': -32.39833296, 'likelihood_delta': -4.129795070000021}}, {'conditioners': ['The occurrence of cold weather events and chilly temperatures can be used to question the assertion that there is a gradual increase in global temperatures due to human actions.'], 'likelihood_delta': {'p_xy': -130.54090005400002, 'p_x': -92.27123441399999, 'p_y': -32.39833296, 'likelihood_delta': -5.87133268000003}}, {'conditioners': ['The ability of renewable energy sources to fully replace fossil fuels is contested, with skeptics questioning their efficiency and overall potential to meet global energy demands.'], 'likelihood_delta': {'p_xy': -113.17286746439999, 'p_x': -78.6054044721, 'p_y': -32.39833296, 'likelihood_delta': -2.1691300322999822}}, {'conditioners': ["Climate change can be seen as a part of Earth's natural cycle, and the extent to which human activities influence this process is still a subject of debate within the scientific community."], 'likelihood_delta': {'p_xy': -97.0191058132, 'p_x': -64.7372980911, 'p_y': -32.39833296, 'likelihood_delta': 0.11652523789999947}}]}
# {'text': {'date': '2024-01-08', 'speakername': 'b', 'text': 'The economic impact of transitioning to renewable energy is too great and will harm our economy.'}, 'likelihood_deltas': [{'conditioners': ['The ability of renewable energy sources to fully replace fossil fuels is contested, with skeptics questioning their efficiency and overall potential to meet global energy demands.'], 'likelihood_delta': {'p_xy': -126.79437747730002, 'p_x': -78.6054044721, 'p_y': -50.66367376, 'likelihood_delta': 2.47470075479999}}, {'conditioners': ['The occurrence of cold weather events and chilly temperatures can be used to question the assertion that there is a gradual increase in global temperatures due to human actions.'], 'likelihood_delta': {'p_xy': -141.28139410599996, 'p_x': -92.27123441399999, 'p_y': -50.66367376, 'likelihood_delta': 1.6535140680000282}}, {'conditioners': ["Climate change can be seen as a part of Earth's natural cycle, and the extent to which human activities influence this process is still a subject of debate within the scientific community."], 'likelihood_delta': {'p_xy':
}]}
# {'text': {'date': '2024-01-08', 'speakername': 'b', 'text': "Renewable energy is too expensive and unreliable right now, it's not worth jeopardizing our economy over unproven climate change fears."}, 'likelihood_deltas': [{'conditioners': ['The ability of renewable energy sources to fully replace fossil fuels is contested, with skeptics questioning their efficiency and overall potential to meet global energy demands.'], 'likelihood_delta': {'p_xy': -154.87490016024, 'p_x': -78.6054044721, 'p_y': -72.55974767539999, 'likelihood_delta': -3.7097480127400075}}, {'conditioners': ['The occurrence of cold weather events and chilly temperatures can be used to question the assertion that there is a gradual increase in global temperatures due to human actions.'], 'likelihood_delta': {'p_xy': -167.7033545796999, 'p_x': -92.27123441399999, 'p_y': -72.55974767539999, 'likelihood_delta': -2.8723724902999095}}, {'conditioners': ["Climate change can be seen as a part of Earth's natural cycle, and the extent to which human activities influence this process is still a subject of debate within the scientific community."], 'likelihood_delta': {'p_xy': -134.18842675110002, 'p_x': -64.7372980911, 'p_y': -72.55974767539999, 'likelihood_delta': 3.1086190153999667}}, {'conditioners': ['Despite the consensus narrative, some argue that climate change discussions are ongoing and that there is not complete agreement on the human impact.'], 'likelihood_delta': {'p_xy': -155.42963672519994, 'p_x': -82.23467644999998, 'p_y': -72.55974767539999, 'likelihood_delta': -0.6352125997999707}}, {'conditioners': ['Some believe that organisms have the capacity to adapt to changes in their climate, suggesting that the effects of climate change may not be as dire as often portrayed.'], 'likelihood_delta': {'p_xy': -147.62914143199998, 'p_x': -70.250260893, 'p_y': -72.55974767539999, 'likelihood_delta': -4.8191328635999895}}]}
# {'text': {'date': '2024-01-08', 'speakername': 'a', 'text': 'The overwhelming consensus among scientists is that human activities, particularly the burning of fossil fuels, are accelerating climate change and its catastrophic impacts.'}, 'likelihood_deltas': [{'conditioners': ['Some believe that organisms have the capacity to adapt to changes in their climate, suggesting that the effects of climate change may not be as dire as often portrayed.'], 'likelihood_delta': {'p_xy': -116.52128267639996, 'p_x': -70.250260893, 'p_y': -50.876996676000005, 'likelihood_delta': 4.605974892600045}}, {'conditioners': ["Climate change can be seen as a part of Earth's natural cycle, and the extent to which human activities influence this process is still a subject of debate within the scientific community."], 'likelihood_delta': {'p_xy': -104.68467054359999, 'p_x': -64.7372980911, 'p_y': -50.876996676000005, 'likelihood_delta': 10.929624223500014}}, {'conditioners': ['Despite the consensus narrative, some argue that climate change discussions are ongoing and that there is not complete agreement on the human impact.'], 'likelihood_delta': {'p_xy': -126.38973518500003, 'p_x': -82.23467644999998, 'p_y': -50.876996676000005, 'likelihood_delta': 6.7219379409999505}}, {'conditioners': ['The occurrence of cold weather events and chilly temperatures can be used to question the assertion that there is a gradual increase in global temperatures due to human actions.'], 'likelihood_delta': {'p_xy': -140.80135207500004, 'p_x': -92.27123441399999, 'p_y': -50.876996676000005, 'likelihood_delta': 2.3468790149999563}}, {'conditioners': ['The ability of renewable energy sources to fully replace fossil fuels is contested, with skeptics questioning their efficiency and overall potential to meet global energy demands.'], 'likelihood_delta': {'p_xy': -131.99300076956004, 'p_x': -78.6054044721, 'p_y': -50.876996676000005, 'likelihood_delta': -2.510599621460031}}]}
# {'text': {'date': '2024-01-08', 'speakername': 'a', 'text': 'Rising sea levels, more frequent wildfires, and severe hurricanes are direct consequences of global warming, primarily caused by human-induced emissions.'}, 'likelihood_deltas': [{'conditioners': ['The ability of renewable energy sources to fully replace fossil fuels is contested, with skeptics questioning their efficiency and overall potential to meet global energy demands.'], 'likelihood_delta': {'p_xy': -139.13585814836, 'p_x': -78.6054044721, 'p_y': -66.55544938050001, 'likelihood_delta': 6.024995704240013}}, {'conditioners': ['Some believe that organisms have the capacity to adapt to changes in their climate, suggesting that the effects of climate change may not be as dire as often portrayed.'], 'likelihood_delta': {'p_xy': -132.76795095, 'p_x': -70.250260893, 'p_y': -66.55544938050001, 'likelihood_delta': 4.037759323500012}}, {'conditioners': ['Despite the consensus narrative, some argue that climate change discussions are ongoing and that there is not complete agreement on the human impact.'], 'likelihood_delta': {'p_xy': -142.97315789449993, 'p_x': -82.23467644999998, 'p_y': -66.55544938050001, 'likelihood_delta': 5.816967936000054}}, {'conditioners': ["Climate change can be seen as a part of Earth's natural cycle, and the extent to which human activities influence this process is still a subject of debate within the scientific community."], 'likelihood_delta': {'p_xy': -126.9501588901, 'p_x': -64.7372980911, 'p_y': -66.55544938050001, 'likelihood_delta': 4.34258858150001}}, {'conditioners': ['The occurrence of cold weather events and chilly temperatures can be used to question the assertion that there is a gradual increase in global temperatures due to human actions.'], 'likelihood_delta': {'p_xy': -155.669480887, 'p_x': -92.27123441399999, 'p_y': -66.55544938050001, 'likelihood_delta': 3.1572029075000074}}]}
# {'text': {'date': '2024-01-08', 'speakername': 'b', 'text': "Historical data shows that the Earth's climate has always gone through cycles of warming and cooling, independent of human activity."}, 'likelihood_deltas': [{'conditioners': ['Some believe that organisms have the capacity to adapt to changes in their climate, suggesting that the effects of climate change may not be as dire as often portrayed.'], 'likelihood_delta': {'p_xy': -107.9015889193, 'p_x': -70.250260893, 'p_y': -41.8538872305, 'likelihood_delta': 4.202559204200007}}, {'conditioners': ['The occurrence of cold weather events and chilly temperatures can be used to question the assertion that there is a gradual increase in global temperatures due to human actions.'], 'likelihood_delta': {'p_xy': -129.339904869, 'p_x': -92.27123441399999, 'p_y': -41.8538872305, 'likelihood_delta': 4.785216775499983}}, {'conditioners': ['The ability of renewable energy sources to fully replace fossil fuels is contested, with skeptics questioning their efficiency and overall potential to meet global energy demands.'], 'likelihood_delta': {'p_xy': -125.58373013309999, 'p_x': -78.6054044721, 'p_y': -41.8538872305, 'likelihood_delta': -5.1244384304999855}}, {'conditioners': ['Despite the consensus narrative, some argue that climate change discussions are ongoing and that there is not complete agreement on the human impact.'], 'likelihood_delta': {'p_xy': -120.10411133969998, 'p_x': -82.23467644999998, 'p_y': -41.8538872305, 'likelihood_delta': 3.984452340799997}}, {'conditioners': ["Climate change can be seen as a part of Earth's natural cycle, and the extent to which human activities influence this process is still a subject of debate within the scientific community."], 'likelihood_delta': {'p_xy': -98.57574998159998, 'p_x': -64.7372980911, 'p_y': -41.8538872305, 'likelihood_delta': 8.015435340000018}}]}
# {'text': {'date': '2024-01-08', 'speakername': 'b', 'text': "The role of CO2 and other greenhouse gases emitted by human activities is overstated, considering the vast natural processes that have governed Earth's climate for millennia."}, 'likelihood_deltas': [{'conditioners': ["Climate change can be seen as a part of Earth's natural cycle, and the extent to which human activities influence this process is still a subject of debate within the scientific community."], 'likelihood_delta': {'p_xy': -135.80483340309996, 'p_x': -64.7372980911, 'p_y': -81.924406302, 'likelihood_delta': 10.856870990000033}}, {'conditioners': ['Some believe that organisms have the capacity to adapt to changes in their climate, suggesting that the effects of climate change may not be as dire as often portrayed.'], 'likelihood_delta': {'p_xy': -146.12613621729997, 'p_x': -70.250260893, 'p_y': -81.924406302, 'likelihood_delta': 6.048530977700025}}, {'conditioners': ['The occurrence of cold weather events and chilly temperatures can be used to question the assertion that there is a gradual increase in global temperatures due to human actions.'], 'likelihood_delta': {'p_xy': -162.88025052799992, 'p_x': -92.27123441399999, 'p_y': -81.924406302, 'likelihood_delta': 11.315390188000066}}, {'conditioners': ['The ability of renewable energy sources to fully replace fossil fuels is contested, with skeptics questioning their efficiency and overall potential to meet global energy demands.'], 'likelihood_delta': {'p_xy': -165.51376455429997, 'p_x': -78.6054044721, 'p_y': -81.924406302, 'likelihood_delta': -4.983953780199968}}, {'conditioners': ['Despite the consensus narrative, some argue that climate change discussions are ongoing and that there is not complete agreement on the human impact.'], 'likelihood_delta': {'p_xy': -159.07313111800008, 'p_x': -82.23467644999998, 'p_y': -81.924406302, 'likelihood_delta': 5.085951633999898}}]}
# {'text': {'date': '2024-01-08', 'speakername': 'a', 'text': "The unprecedented rate of global warming we're experiencing can only be explained by the massive increase in CO2 emissions from burning fossil fuels."}, 'likelihood_deltas': [{'conditioners': ['The occurrence of cold weather events and chilly temperatures can be used to question the assertion that there is a gradual increase in global temperatures due to human actions.'], 'likelihood_delta': {'p_xy': -148.83137243699997, 'p_x': -92.27123441399999, 'p_y': -53.99227883499999, 'likelihood_delta': -2.5678591879999857}}, {'conditioners': ["Climate change can be seen as a part of Earth's natural cycle, and the extent to which human activities influence this process is still a subject of debate within the scientific community."], 'likelihood_delta': {'p_xy': -113.5983016311, 'p_x': -64.7372980911, 'p_y': -53.99227883499999, 'likelihood_delta': 5.131275294999995}}, {'conditioners': ['The ability of renewable energy sources to fully replace fossil fuels is contested, with skeptics questioning their efficiency and overall potential to meet global energy demands.'], 'likelihood_delta': {'p_xy': -139.21492977440008, 'p_x': -78.6054044721, 'p_y': -53.99227883499999, 'likelihood_delta': -6.6172464673000775}}, {'conditioners': ['Despite the consensus narrative, some argue that climate change discussions are ongoing and that there is not complete agreement on the human impact.'], 'likelihood_delta': {'p_xy': -137.44730874499996, 'p_x': -82.23467644999998, 'p_y': -53.99227883499999, 'likelihood_delta': -1.2203534599999841}}, {'conditioners': ['Some believe that organisms have the capacity to adapt to changes in their climate, suggesting that the effects of climate change may not be as dire as often portrayed.'], 'likelihood_delta': {'p_xy': -124.26878553100002, 'p_x': -70.250260893, 'p_y': -53.99227883499999, 'likelihood_delta': -0.026245803000023216}}]}
# {'text': {'date': '2024-01-08', 'speakername': 'a', 'text': 'Scientific consensus confirms that human activities, particularly since the Industrial Revolution, have significantly accelerated climate change.'}, 'likelihood_deltas': [{'conditioners': ["Climate change can be seen as a part of Earth's natural cycle, and the extent to which human activities influence this process is still a subject of debate within the scientific community."], 'likelihood_delta': {'p_xy': -106.07183660410001, 'p_x': -64.7372980911, 'p_y': -40.896354822999996, 'likelihood_delta': -0.43818369000001667}}, {'conditioners': ['Despite the consensus narrative, some argue that climate change discussions are ongoing and that there is not complete agreement on the human impact.'], 'likelihood_delta': {'p_xy': -127.34146911999999, 'p_x': -82.23467644999998, 'p_y': -40.896354822999996, 'likelihood_delta': -4.210437847000009}}, {'conditioners': ['The occurrence of cold weather events and chilly temperatures can be used to question the assertion that there is a gradual increase in global temperatures due to human actions.'], 'likelihood_delta': {'p_xy': -138.25094843800002, 'p_x': -92.27123441399999, 'p_y': -40.896354822999996, 'likelihood_delta': -5.083359201000036}}, {'conditioners': ['The ability of renewable energy sources to fully replace fossil fuels is contested, with skeptics questioning their efficiency and overall potential to meet global energy demands.'], 'likelihood_delta': {'p_xy': -126.9007264283, 'p_x': -78.6054044721, 'p_y': -40.896354822999996, 'likelihood_delta': -7.398967133200003}}, {'conditioners': ['Some believe that organisms have the capacity to adapt to changes in their climate, suggesting that the effects of climate change may not be as dire as often portrayed.'], 'likelihood_delta': {'p_xy': -112.814190162, 'p_x': -70.250260893, 'p_y': -40.896354822999996, 'likelihood_delta': -1.6675744460000033}}]}
# {'text': {'date': '2024-01-08', 'speakername': 'b', 'text': 'The Earth has gone through many natural warming and cooling phases long before humans were around to contribute.'}, 'likelihood_deltas': [{'conditioners': ['Despite the consensus narrative, some argue that climate change discussions are ongoing and that there is not complete agreement on the human impact.'], 'likelihood_delta': {'p_xy': -122.51555419099998, 'p_x': -82.23467644999998, 'p_y': -48.880502772, 'likelihood_delta': 8.599625031000002}}, {'conditioners': ['Some believe that organisms have the capacity to adapt to changes in their climate, suggesting that the effects of climate change may not be as dire as often portrayed.'], 'likelihood_delta': {'p_xy': -110.60093077500001, 'p_x': -70.250260893, 'p_y': -48.880502772, 'likelihood_delta': 8.529832889999994}}, {'conditioners': ['The ability of renewable energy sources to fully replace fossil fuels is contested, with skeptics questioning their efficiency and overall potential to meet global energy demands.'], 'likelihood_delta': {'p_xy': -130.18685401880003, 'p_x': -78.6054044721, 'p_y': -48.880502772, 'likelihood_delta': -2.7009467747000286}}, {'conditioners': ["Climate change can be seen as a part of Earth's natural cycle, and the extent to which human activities influence this process is still a subject of debate within the scientific community."], 'likelihood_delta': {'p_xy': -101.93686576489999, 'p_x': -64.7372980911, 'p_y': -48.880502772, 'likelihood_delta': 11.68093509820001}}, {'conditioners': ['The occurrence of cold weather events and chilly temperatures can be used to question the assertion that there is a gradual increase in global temperatures due to human actions.'], 'likelihood_delta': {'p_xy': -132.545259112, 'p_x': -92.27123441399999, 'p_y': -48.880502772, 'likelihood_delta': 8.606478073999995}}]}
# {'text': {'date': '2024-01-08', 'speakername': 'b', 'text': 'Volcanic eruptions release far more carbon dioxide into the atmosphere than human activities ever could.'}, 'likelihood_deltas': [{'conditioners': ['Some believe that organisms have the capacity to adapt to changes in their climate, suggesting that the effects of climate change may not be as dire as often portrayed.'], 'likelihood_delta': {'p_xy': -104.21231742812002, 'p_x': -70.250260893, 'p_y': -33.11104018765, 'likelihood_delta': -0.851016347470015}}, {'conditioners': ["Climate change can be seen as a part of Earth's natural cycle, and the extent to which human activities influence this process is still a subject of debate within the scientific community."], 'likelihood_delta': {'p_xy': -95.27495646772998, 'p_x': -64.7372980911, 'p_y': -33.11104018765, 'likelihood_delta': 2.5733818110200204}}, {'conditioners': ['Despite the consensus narrative, some argue that climate change discussions are ongoing and that there is not complete agreement on the human impact.'], 'likelihood_delta': {'p_xy': -116.35689169669503, 'p_x': -82.23467644999998, 'p_y': -33.11104018765, 'likelihood_delta': -1.0111750590450512}}, {'conditioners': ['The ability of renewable energy sources to fully replace fossil fuels is contested, with skeptics questioning their efficiency and overall potential to meet global energy demands.'], 'likelihood_delta': {'p_xy': -115.86051673877999, 'p_x': -78.6054044721, 'p_y': -33.11104018765, 'likelihood_delta': -4.144072079029989}}, {'conditioners': ['The occurrence of cold weather events and chilly temperatures can be used to question the assertion that there is a gradual increase in global temperatures due to human actions.'], 'likelihood_delta': {'p_xy': -126.84199412083998, 'p_x': -92.27123441399999, 'p_y': -33.11104018765, 'likelihood_delta': -1.4597195191899957}}]}
# Most unhelpful:
# [-7.300244565048013] The idea that we're in a climate crisis is overblown; we should focus on economic growth instead of costly green energy solutions.
# [-4.512209754260008] Climate change concerns are overblown and shouldn't dictate our energy policies.
# [-3.89721239492002] Historical data shows that the Earth's climate has always gone through cycles of warming and cooling, independent of human activity.
# [-3.3831997804199903] The economic impact of transitioning to renewable energy is too great and will harm our economy.
# [-2.41433699248004] Renewable energy is too expensive and unreliable right now, it's not worth jeopardizing our economy over unproven climate change fears.
# [-2.0337349486800056] The Earth has gone through many natural warming and cooling phases long before humans were around to contribute.
# [-2.032729644536401] Volcanic eruptions release far more carbon dioxide into the atmosphere than human activities ever could.
# [-0.009770337240018634] The role of CO2 and other greenhouse gases emitted by human activities is overstated, considering the vast natural processes that have governed Earth's climate for millennia.
# [2.180992551239997] Immediate global action is required to reduce carbon emissions and save our planet.
# [2.969531511171975] Rising sea levels, more frequent wildfires, and severe hurricanes are direct consequences of global warming, primarily caused by human-induced emissions.
#
# Most helpful:
# [-2.032729644536401] Volcanic eruptions release far more carbon dioxide into the atmosphere than human activities ever could.
# [-0.009770337240018634] The role of CO2 and other greenhouse gases emitted by human activities is overstated, considering the vast natural processes that have governed Earth's climate for millennia.
# [2.180992551239997] Immediate global action is required to reduce carbon emissions and save our planet.
# [2.969531511171975] Rising sea levels, more frequent wildfires, and severe hurricanes are direct consequences of global warming, primarily caused by human-induced emissions.
# [3.134485743731993] The overwhelming consensus among scientists is that human activities, particularly the burning of fossil fuels, are accelerating climate change and its catastrophic impacts.
# [4.083369399199994] Scientific consensus confirms that human activities, particularly since the Industrial Revolution, have significantly accelerated climate change.
# [4.352611146960017] We must invest in solar and wind energy now to prevent catastrophic climate change impacts.
# [4.372360775059995] Ignoring the climate crisis in favor of short-term economic gains is irresponsible; we owe it to future generations to invest in renewable energy.
# [4.442163997959999] The unprecedented rate of global warming we're experiencing can only be explained by the massive increase in CO2 emissions from burning fossil fuels.
# [4.90431466245199] We must act now to combat climate change, transitioning to renewable energy is essential for the survival of our planet.
