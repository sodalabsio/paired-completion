# %%
from soda.openai.text import instruct_chat_model, instruct_chat_model_batched
import json

with open("book.txt") as f:
    book = f.read()

# Chunk the book into 4096 word chunks with 1024 word overlap
chunks = []
for i in range(0, len(book), (4096 - 1024)):
    chunks.append(book[i:i+4096])

print("Loaded {} chunks".format(len(chunks)))
# Choose the first 10 chunks
chunks = chunks[:50]

SYSTEM_MESSAGE = """
Output

YES

if the text explicitly contains either a recipe, or part of a recipe. Otherwise, output

NO

If it only discusses recipes, output NO.
""".strip()

# resp = instruct_chat_model(
#     SYSTEM_MESSAGE,
#     chunks[0],
#     model="gpt-4"
# )

# answer = resp["choices"][0]["message"]["content"]
# print(answer)

resps = instruct_chat_model_batched(
    SYSTEM_MESSAGE,
    chunks,
    model="gpt-4"
)
# Out:
# Loaded 99 chunks
# 100%|██████████| 50/50 [00:00<00:00, 3894.72it/s]

# %%
evaluations = [1 if resps[i]["choices"][0]["message"]["content"] == "YES" else 0 for i in range(len(resps))]

# for chunk, evaluation in zip(chunks, evaluations):
#     print(chunk[:50] + "...")
#     print(evaluation)
#     print()

print("{}/{} chunks contain recipes".format(sum(evaluations), len(evaluations)))

for i in range(len(resps)):
    print("Chunk {}:".format(i))
    print(resps[i]["choices"][0]["message"]["content"])
    print()

# Gather all chunks with blocks
blocks = [chunks[i] for i in range(len(chunks)) if evaluations[i] == 1]

# Add line numbering to blocks
blocks = ["".join(["{}: {}\n".format(i, line) for i, line in enumerate(block.split("\n"))]) for block in blocks]
blocks = blocks[:10]

SYSTEM_MESSAGE = """
Output the start and end lines of the recipes in the text. If a recipe is cut-off (at the start or the end), output 0 or -1 respectively for the start or end line.
Give your response as a list of pairs of numbers, e.g.
0 23
34 45
46 -1
""".strip()

block_resps = instruct_chat_model_batched(
    SYSTEM_MESSAGE,
    blocks,
    model="gpt-4"
)

for i in range(len(block_resps)):
    print("Chunk {}:".format(i))
    print(block_resps[i]["choices"][0]["message"]["content"])
    print()
# Out:
# 34/50 chunks contain recipes
# Chunk 0:
# NO
#
# Chunk 1:
# NO
#
# Chunk 2:
# NO
#
# Chunk 3:
# NO
#
# Chunk 4:
# NO
#
# Chunk 5:
# NO
#
# Chunk 6:
# NO
#
# Chunk 7:
# NO
#
# Chunk 8:
# NO
#
# Chunk 9:
# NO
#
# Chunk 10:
# YES
#
# Chunk 11:
# YES
#
# Chunk 12:
# YES
#
# Chunk 13:
# NO
#
# Chunk 14:
# NO
#
# Chunk 15:
# NO
#
# Chunk 16:
# NO
#
# Chunk 17:
# YES
#
# Chunk 18:
# YES
#
# Chunk 19:
# NO
#
# Chunk 20:
# NO
#
# Chunk 21:
# YES
#
# Chunk 22:
# YES
#
# Chunk 23:
# YES
#
# Chunk 24:
# YES
#
# Chunk 25:
# YES
#
# Chunk 26:
# YES
#
# Chunk 27:
# YES
#
# Chunk 28:
# YES
#
# Chunk 29:
# YES
#
# Chunk 30:
# YES
#
# Chunk 31:
# YES
#
# Chunk 32:
# YES
#
# Chunk 33:
# YES
#
# Chunk 34:
# YES
#
# Chunk 35:
# YES
#
# Chunk 36:
# YES
#
# Chunk 37:
# YES
#
# Chunk 38:
# YES
#
# Chunk 39:
# YES
#
# Chunk 40:
# YES
#
# Chunk 41:
# YES
#
# Chunk 42:
# YES
#
# Chunk 43:
# YES
#
# Chunk 44:
# YES
#
# Chunk 45:
# YES
#
# Chunk 46:
# YES
#
# Chunk 47:
# YES
#
# Chunk 48:
# YES
#
# Chunk 49:
# YES
# 100%|██████████| 10/10 [00:00<00:00, 71575.15it/s]
# Chunk 0:
# 0 81
#
# Chunk 1:
# 0 0
# 29 37
#
# Chunk 2:
# 0 -1
#
# Chunk 3:
# 0 0
# 73 -1
#
# Chunk 4:
# 9 84
#
# Chunk 5:
# 0 45
# 79 -1
#
# Chunk 6:
# 21 26
# 35 40
# 46 51
# 59 65
# 71 78
# 88 94
# 109 -1
#
# Chunk 7:
# 5 23
# 26 42
# 45 53
# 56 64
# 67 75
# 78 89
# 92 103
# 106 117
# 120 -1
#
# Chunk 8:
# 0 2
# 10 17
# 24 30
# 38 42
# 50 55
# 61 68
# 81 87
# 95 100
# 107 -1
#
# Chunk 9:
# 0 8
# 9 21
# 22 46
# 47 65
# 66 80
# 81 96
# 97 -1

# %%
# Extract the start and end lines of the recipes from the responses
recipe_lines = []
for i in range(len(block_resps)):
    lines = block_resps[i]["choices"][0]["message"]["content"].split('\n')
    for line in lines:
        if line:  # Ignore empty lines
            start, end = map(int, line.split())
            recipe_lines.append((blocks[i], start, end))

print("Found {} recipes".format(len(recipe_lines)))
# Extract the recipes from the blocks using the start and end lines
recipes = []
for (block, start, end) in recipe_lines:
    lines = block.split('\n')
    if end == -1:  # If the recipe is cut-off at the end
        end = len(lines)  # Use the last line
    recipe = '\n'.join(lines[start:end+1])
    recipes.append((recipe, start, end))

# Print the recipes individually
for i, (recipe, start, end) in enumerate(recipes, 1):
    print("*** Recipe {} (lines {}-{}) ***".format(i, start, end))
    print(recipe)
    print()

# Save recipes to JSON
with open("recipes.json", "w") as f:
    json.dump(recipes, f)
# Out:
# Found 41 recipes
# *** Recipe 1 (lines 0-81) ***
# 0: not only frequently used,
# 1: but was of various sorts, as _cypre_, No. 41. 99. 120. named probably
# 2: from the isle of Cyprus, whence it might either come directly to us,
# 3: or where it had received some improvement by way of refining. There
# 4: is mention of _blanch-powder or white sugar_, 132. They, however,
# 5: were not the same, for see No. 193. Sugar was clarified sometimes
# 6: with wine [105].
# 7:
# 8: Spices. _Species_. They are mentioned in general No. 133, and _whole
# 9: spices_, 167, 168. but they are more commonly specified, and are
# 10: indeed greatly used, though being imported from abroad, and from so
# 11: far as Italy or the Levant (and even there must be dear), some may
# 12: wonder at this: but it shouid be considered, that our Roll was
# 13: chiefly compiled for the use of noble and princely tables; and the
# 14: same may be said of the Editor's MS. The spices came from the same
# 15: part of the world, and by the same route, as sugar did. The _spicery_
# 16: was an ancient department at court, and had its proper officers.
# 17:
# 18: As to the particular sorts, these are,
# 19:
# 20: Cinamon. _Canell_. 14. 191. _Canel_, Editor's MS. 10. _Kanell_, ibid.
# 21: 32. is the Italian _Canella_. See Chaucer. We have the flour or
# 22: powder, No. 20. 62. See Wiclif. It is not once mentioned in Apicius.
# 23:
# 24: Macys, 14. 121. Editor's MS. 10. _Maces_, 134. Editor's MS. 27. They
# 25: are used whole, No. 158. and are always expressed plurally, though we
# 26: now use the singular, _mace_. See Junii Etym.
# 27:
# 28: Cloves. No. 20. Dishes are flourished with them, 22. 158. Editor's MS.
# 29: 10. 27. where we have _clowys gylofres_, as in our Roll, No. 104.
# 30: _Powdour gylofre_ occurs 65. 191. Chaucer has _clowe_ in the singular,
# 31: and see him v. Clove-gelofer.
# 32:
# 33: Galyngal, 30. and elsewhere. Galangal, the long rooted cyperus [106],
# 34: is a warm cardiac and cephalic. It is used in powder, 30. 47. and was
# 35: the chief ingredient in _galentine_, which, I think, took its name
# 36: from it.
# 37:
# 38: Pepper. It appears from Pliny that this pungent, warm seasoning, so
# 39: much in esteem at Rome [107], came from the East Indies [108], and,
# 40: as we may suppose, by way of Alexandria. We obtained it no doubt, in
# 41: the 14th century, from the same quarter, though not exactly by the
# 42: same route, but by Venice or Genoa. It is used both whole, No. 35,
# 43: and in powder, No. 83. And long-pepper occurs, if we read the place
# 44: rightly, in No. 191.
# 45:
# 46: Ginger, gyngyn. 64. 136. alibi. Powder is used, 17. 20. alibi. and
# 47: Rabelais IV. c. 59. the white powder, 131. and it is the name of a
# 48: mess, 139. quære whether _gyngyn_ is not misread for _gyngyr_, for
# 49: see Junii Etym. The Romans had their ginger from Troglodytica [109].
# 50:
# 51: Cubebs, 64. 121. are a warm spicy grain from the east.
# 52:
# 53: Grains of Paradice, or _de parys_, 137. [110] are the greater
# 54: cardamoms.
# 55:
# 56: Noix muscadez, 191. nutmegs.
# 57:
# 58: The caraway is once mentioned, No. 53. and was an exotic from _Caria_,
# 59: whence, according to Mr. Lye, it took its name: 'sunt semina, inquit,
# 60: _carri_ vel _carrei_, sic dicti a Caria, ubi copiosissimè nascitur
# 61: [111].'
# 62:
# 63: Powder-douce, which occurs so often, has been thought by some, who
# 64: have just peeped into our Roll, to be the same as sugar, and only a
# 65: different name for it; but they are plainly mistaken, as is evident
# 66: from 47. 51. 164. 165. where they are mentioned together as different
# 67: things. In short, I take powder-douce to be either powder of
# 68: galyngal, for see Editor's MS II. 20. 24, or a compound made of
# 69: sundry aromatic spices ground or beaten small, and kept always ready
# 70: at hand in some proper receptacle. It is otherwise termed _good
# 71: powders_, 83. 130. and in Editor's MS 17. 37. 38 [112]. or _powder_
# 72: simply, No. 169, 170. _White powder-douce_ occurs No. 51, which seems
# 73: to be the same as blanch-powder, 132. 193. called _blaynshe powder_,
# 74: and bought ready prepared, in Northumb. Book, p. 19. It is sometimes
# 75: used with powder-fort, 38. 156. for which see the next and last
# 76: article.
# 77:
# 78: Powder-fort, 10. 11. seems to be a mixture likewise of the warmer
# 79: spices, pepper, ginger, &c. pulverized: hence we have _powder-fort of
# 80: gynger, other of canel_, 14. It is called _strong powder_, 22. and
# 81: perhaps may sometimes be intended by _good powders_. If you will
#
# *** Recipe 2 (lines 0-0) ***
# 0: and only a
#
# *** Recipe 3 (lines 29-37) ***
# 29: [Illustration: Take þe chese and of flessh of capouns, or of hennes
# 30: & hakke smal and grynde hem smale inn a morter, take mylke of
# 31: almandes with þe broth of freysh beef. oþer freysh flessh, & put the
# 32: flessh in þe mylke oþer in the broth and set hem to þe fyre, & alye
# 33: hem with flour of ryse, or gastbon, or amydoun as chargeaunt as þe
# 34: blank desire, & with zolks of ayren and safroun for to make hit zelow,
# 35: and when it is dressit in dysshes with blank desires; styk aboue
# 36: clowes de gilofre, & strawe powdour of galyugale above, and serue it
# 37: forth.]
#
# *** Recipe 4 (lines 0-81) ***
# 0: tain contemporary writers, such as the Editor's MS,
# 1: of which we shall speak more particularly hereafter, Chaucer, and
# 2: Wiclif; with whom we have associated Junius' Etymologicon Anglicanum.
# 3:
# 4: As the abbreviations of the Roll are here retained, in order to
# 5: establish and confirm the age of it, it has been thought proper to
# 6: adopt the types which our printer had projected for Domesday-Book,
# 7: with which we find that our characters very nearly coincide.
# 8:
# 9: The names of the dishes and sauces have occasioned the greatest
# 10: perplexity. These are not only many in number, but are often so
# 11: horrid and barbarous, to our ears at least, as to be inveloped in
# 12: several instances in almost impenetrable obscurity. Bishop Godwin
# 13: complains of this so long ago as 1616 [115]. The _Contents_ prefixed
# 14: will exhibit at once a most formidable list of these hideous names
# 15: and titles, so that there is no need to report them here. A few of
# 16: these terms the Editor humbly hopes he has happily enucleated, but
# 17: still, notwithstanding all his labour and pains, the argument is in
# 18: itself so abstruse at this distance of time, the helps so few, and
# 19: his abilities in this line of knowledge and science so slender and
# 20: confined, that he fears he has left the far greater part of the task
# 21: for the more sagacious reader to supply: indeed, he has not the least
# 22: doubt, but other gentlemen of curiosity in such matters (and this
# 23: publication is intended for them alone) will be so happy as to clear
# 24: up several difficulties, which appear now to him insuperable. It must
# 25: be confessed again, thatthe Editor may probably have often failed in
# 26: those very points, which he fancies and flatters himself to have
# 27: elucidated, but this he is willing to leave to the candour of the
# 28: public.
# 29:
# 30: Now in regard to the helps I mentioned; there is not much to be
# 31: learnt from the Great Inthronization-feast of archbishop Robert
# 32: Winchelsea, A. 1295, even if it were his; but I rather think it
# 33: belongs to archbishop William Warham, A. 1504 [116]. Some use,
# 34: however, has been made of it.
# 35:
# 36: Ralph Bourne was installed abbot of St. Augustine's, near Canterbury,
# 37: A. 1309; and William Thorne has inserted a list of provisions bought
# 38: for the feast, with their prices, in his Chronicle [117].
# 39:
# 40: The Great Feast at the Inthronization of George Nevile archbishop of
# 41: York, 6 Edward IV. is printed by Mr. Hearne [118], and has been of
# 42: good service.
# 43:
# 44: Elizabeth, queen of king Henry VII. was crowned A. 1487, and the
# 45: messes at the dinner, in two courses, are registered in the late
# 46: edition of Leland's Collectenea, A. 1770 [119], and we have profited
# 47: thereby.
# 48:
# 49: The Lenten Inthronization-feast of archbishop William Warham, A. 1504
# 50: [120], given us at large by Mr. Hearne [121], has been also consulted.
# 51:
# 52: There is a large catalogue of viands in Rabelais, lib. iv. cap. 59.
# 53: 60. And the English translation of Mr. Ozell affording little
# 54: information, I had recourse to the French original, but not to much
# 55: more advantage.
# 56:
# 57: There is also a Royal Feast at the wedding of the earl of Devonshire,
# 58: in the Harleian Misc. No. 279, and it has not been neglected.
# 59:
# 60: Randle Holme, in his multifarious _Academy of Armory_, has an
# 61: alphabet of terms and dishes [122]; but though I have pressed him
# 62: into the service, he has not contributed much as to the more
# 63: difficult points.
# 64:
# 65: The Antiquarian Repertory, vol. II. p. 211, exhibits an
# 66: entertainment of the mayor of Rochester, A. 1460; but there is little
# 67: to be learned from thence. The present work was printed before No. 31
# 68: of the Antiquarian Repertory, wherein some ancient recipes in Cookery
# 69: are published, came to the Editor's hand.
# 70:
# 71: I must not omit my acknowledgments to my learned friend the present
# 72: dean of Carlisle, to whom I stand indebted for his useful notes on
# 73: the Northumberland-Household Book, as also for the book itself.
# 74:
# 75: Our chief assistance, however, has been drawn from a MS belonging to
# 76: the Editor, denoted, when cited, by the signature _MS. Ed._ It is a
# 77: vellum miscellany in small quarto, and the part respecting this
# 78: subject consists of ninety-one English recipes (or _nyms_) in cookery.
# 79: These are disposed into two parts, and
#
#
# *** Recipe 5 (lines 0-0) ***
# 0: common at table among the Greeks. Casaub. ad
#
# *** Recipe 6 (lines 73-93) ***
# 73: THE
# 74:
# 75: FORME OF CURY.
# 76:
# 77: ... fome [1] of cury [2] was compiled of the chef Maister Cokes of
# 78: kyng Richard the Secunde kyng of .nglond [3] aftir the Conquest. the
# 79: which was acounted þe [4] best and ryallest vyand [5] of alle
# 80: csten .ynges [6] and it was compiled by assent and avysement of
# 81: Maisters and [7] phisik [8] and of philosophie þat dwellid in his
# 82: court. First it techiþ a man for to make commune potages and commune
# 83: meetis for howshold as þey shold be made craftly and holsomly.
# 84: Aftirward it techiþ for to make curious potages & meetes and
# 85: sotiltees [9] for alle maner of States bothe hye and lowe. And the
# 86: techyng of the forme of making of potages & of meetes bothe of flessh
# 87: and of fissh. buth [10] y sette here by noumbre and by ordre. sso þis
# 88: little table here sewyng [11] wole teche a man with oute taryyng: to
# 89: fynde what meete þat hym lust for to have.
# 90:
# 91:
#
#
# *** Recipe 7 (lines 9-84) ***
# 9: FORME OF CURY.
# 10:
# 11: ... fome [1] of cury [2] was compiled of the chef Maister Cokes of
# 12: kyng Richard the Secunde kyng of .nglond [3] aftir the Conquest. the
# 13: which was acounted þe [4] best and ryallest vyand [5] of alle
# 14: csten .ynges [6] and it was compiled by assent and avysement of
# 15: Maisters and [7] phisik [8] and of philosophie þat dwellid in his
# 16: court. First it techiþ a man for to make commune potages and commune
# 17: meetis for howshold as þey shold be made craftly and holsomly.
# 18: Aftirward it techiþ for to make curious potages & meetes and
# 19: sotiltees [9] for alle maner of States bothe hye and lowe. And the
# 20: techyng of the forme of making of potages & of meetes bothe of flessh
# 21: and of fissh. buth [10] y sette here by noumbre and by ordre. sso þis
# 22: little table here sewyng [11] wole teche a man with oute taryyng: to
# 23: fynde what meete þat hym lust for to have.
# 24:
# 25:    or [12] to make gronnden benes . . . . . I.
# 26:   For to make drawen benes. . . . . . . . . II.
# 27:   for to make grewel forced.. . . . . . . . III.
# 28:   Caboches in potage. . . . . . . . . . . . IIII.
# 29:   rapes in potage . . . . . . . . . . . . . V.
# 30:   Eowtes of Flessh. . . . . . . . . . . . . VI.
# 31:   hebolas . . . . . . . . . . . . . . . . . VII.
# 32:   Gowrdes in potage . . . . . . . . . . . . VIII.
# 33:   ryse of Flessh. . . . . . . . . . . . . . IX.
# 34:   Funges. . . . . . . . . . . . . . . . . . X.
# 35:   Bursen. . . . . . . . . . . . . . . . . . XI.
# 36:   Corat . . . . . . . . . . . . . . . . . . XII.
# 37:   noumbles. . . . . . . . . . . . . . . . . XIII.
# 38:   Roobroth. . . . . . . . . . . . . . . . . XIIII.
# 39:   Tredure . . . . . . . . . . . . . . . . . XV.
# 40:   Mounchelet. . . . . . . . . . . . . . . . XVI.
# 41:   Bukkenade . . . . . . . . . . . . . . . . XVII.
# 42:   Connat. . . . . . . . . . . . . . . . . . XVIII.
# 43:   drepee. . . . . . . . . . . . . . . . . . XIX.
# 44:   Mawmenee. . . . . . . . . . . . . . . . . XX.
# 45:   Egurdouce . . . . . . . . . . . . . . . . XXI.
# 46:   Capouns in Conney . . . . . . . . . . . . XXII.
# 47:   haares in talbotes. . . . . . . . . . . . XXIII.
# 48:   Haares in papdele . . . . . . . . . . . . XXIIII.
# 49:   connynges in Cynee. . . . . . . . . . . . XXV.
# 50:   Connynges in gravey . . . . . . . . . . . XXVI.
# 51:   Chykens in gravey . . . . . . . . . . . . XXVII.
# 52:   filetes in galyntyne. . . . . . . . . . . XXVIII.
# 53:   Pigges in sawse sawge . . . . . . . . . . XXIX.
# 54:   sawse madame. . . . . . . . . . . . . . . XXX.
# 55:   Gees in hoggepot. . . . . . . . . . . . . XXXI.
# 56:   carnel of pork. . . . . . . . . . . . . . XXXII.
# 57:   Chikens in Caudell. . . . . . . . . . . . XXXIII.
# 58:   chikens in hocchee. . . . . . . . . . . . XXXIII.
# 59:   For to boyle Fesauntes, Partyches
# 60:   Capons and Curlewes . . . . . . . . . . . XXX. V.
# 61:   blank manng . . . . . . . . . . . . . . . XXXVI.
# 62:   Blank Dessorre. . . . . . . . . . . . . . XXXVII.
# 63:   morree. . . . . . . . . . . . . . . . . . XXXVIII.
# 64:   Charlet . . . . . . . . . . . . . . . . . XXXIX.
# 65:   charlot y forced. . . . . . . . . . . . . XX.II.
# 66:   Cawdel ferry. . . . . . . . . . . . . . . XX.II. I.
# 67:   iusshell. . . . . . . . . . . . . . . . . XX.II. III.[13]
# 68:   Iusshell enforced . . . . . . . . . . . . XX.II. IIII.
# 69:   mortrews. . . . . . . . . . . . . . . . . XX.II. V.
# 70:   Blank mortrews. . . . . . . . . . . . . . XX.II. VI.
# 71:   brewet of almony. . . . . . . . . . . . . XX.II. VII.
# 72:   Peions y stewed . . . . . . . . . . . . . XX.II. VIII.
# 73:   loseyns . . . . . . . . . . . . . . . . . XX.II. IX.
# 74:   Tartletes . . . . . . . . . . . . . . . . XX.II. X.
# 75:   pynnonade . . . . . . . . . . . . . . . . XX.II. XI.
# 76:   Rosee . . . . . . . . . . . . . . . . . . XX.II. XII.
# 77:   cormarye. . . . . . . . . . . . . . . . . XX.II. XIII.
# 78:   New noumbles of Deer. . . . . . . . . . . XX.II. XIIII.
# 79:   nota. . . . . . . . . . . . . . . . . . . XX.II. XV.
# 80:   Nota. . . . . . . . . . . . . . . . . . . XX.II. XVI.
# 81:   ipynee. . . . . . . . . . . . . . . . . . XX.II. XVII.
# 82:   Chyryse . . . . . . . . . . . . . . . . . XX.II. XVIII.
# 83:   payn Foundewe . . . . . . . . . . . . . . XX.II. XIX.
# 84:   Crotoun . . . . . . . . . . . .
#
# *** Recipe 8 (lines 0-45) ***
# 0:  Whyte milates . . . . . . . . . . . . . . XX.VII. XIII.
# 1:   crustardes of flessh. . . . . . . . . . . XX.VII. XIIII.
# 2:   Mylates of Pork . . . . . . . . . . . . . XX.VII. XV.
# 3:   crustardes of Fyssh . . . . . . . . . . . XX.VII. XVI.
# 4:   Crustardes of erbis on fyssh day. . . . . XX.VII. XVII.
# 5:   lesshes fryed in lentoun. . . . . . . . . XX.VII. XVIII.
# 6:   Wastels y farced. . . . . . . . . . . . . XX.VII. XIX.
# 7:   sawge y farced. . . . . . . . . . . . . . XX.VIII.
# 8:   Sawgeat . . . . . . . . . . . . . . . . . XX.VIII. I.
# 9:   cryspes . . . . . . . . . . . . . . . . . XX.VIII. II.
# 10:   Cryspels. . . . . . . . . . . . . . . . . XX.VIII. III.
# 11:   Tartee. . . . . . . . . . . . . . . . . . XX.VIII. IIII.
# 12:   Tart in Ymbre day . . . . . . . . . . . . XX.VIII. V.
# 13:   tart de Bry . . . . . . . . . . . . . . . XX.VIII. VI.
# 14:   Tart de Brymlent. . . . . . . . . . . . . XX.VIII. VII.
# 15:   tartes of Flessh. . . . . . . . . . . . . XX.VIII. VIII.
# 16:   Tartletes . . . . . . . . . . . . . . . . XX.VIII. IX.
# 17:   tartes of Fyssh . . . . . . . . . . . . . XX.VIII. X.
# 18:   Sambocade . . . . . . . . . . . . . . . . XX.VIII. XI.
# 19:   Erbolat . . . . . . . . . . . . . . . . . XX.VIII. XII.
# 20:   Nysebek . . . . . . . . . . . . . . . . . XX.VIII. XIII.
# 21:   for to make Pom Dorryes. & oþer þynges. . XX.VIII. XIIII.
# 22:   Cotagres. . . . . . . . . . . . . . . . . XX.VIII. XV.
# 23:   hart rows . . . . . . . . . . . . . . . . XX.VIII. XVI.
# 24:   Potews. . . . . . . . . . . . . . . . . . XX.VIII. XVII.
# 25:   Sachus. . . . . . . . . . . . . . . . . . XX.VIII. XVIII.
# 26:   Bursews . . . . . . . . . . . . . . . . . XX.VIII. XIX.
# 27:   spynoches y fryed . . . . . . . . . . . . XX.IX.
# 28:   Benes y fryed . . . . . . . . . . . . . . XX.IX. I.
# 29:   russhewses of Fruyt . . . . . . . . . . . XX.IX. II.
# 30:   Daryols . . . . . . . . . . . . . . . . . XX.IX. III.
# 31:   Flaumpens . . . . . . . . . . . . . . . . XX.IX. IIII.
# 32:   Chewetes on flessh day. . . . . . . . . . XX.IX. V.
# 33:   chewetes on fyssh day . . . . . . . . . . XX.IX. VI.
# 34:   Hastletes . . . . . . . . . . . . . . . . XX.XI. VII.
# 35:   comadore. . . . . . . . . . . . . . . . . XX.IX. VIII.
# 36:   Chastletes. . . . . . . . . . . . . . . . XX.IX. IX.
# 37:   for to make twey pecys of Flesshe
# 38:   to fasten to gydre. . . . . . . . . . . . XX.IX. X.
# 39:   pur fait y pocras . . . . . . . . . . . . XX.IX. XI.
# 40:   For to make blank maunnger. . . . . . . . XX.IX. XII.
# 41:   for to make Blank Desire. . . . . . . . . XX.IX. XIII.
# 42:   For to make mawmoune. . . . . . . . . . . XX.IX. XIIII.
# 43:   the pety peruaunt . . . . . . . . . . . . XX.IX. XV.
# 44:   And the pete puant. . . . . . . . . . . . XX.IX. XVI.
# 45:
#
# *** Recipe 9 (lines 79-83) ***
# 79: FOR TO MAKE GRONDEN BENES [1]. I.
# 80:
# 81: Take benes and d
#
#
# *** Recipe 10 (lines 21-26) ***
# 21: FOR TO MAKE GRONDEN BENES [1]. I.
# 22:
# 23: Take benes and dry hem in a nost [2] or in an Ovene and hulle hem
# 24: wele and wyndewe [3] out þe hulk and wayshe hem clene an do hem to
# 25: seeþ in gode broth [4] an ete hem with Bacon.
# 26:
#
# *** Recipe 11 (lines 35-40) ***
# 35: FOR TO MAKE DRAWEN BENES. II.
# 36:
# 37: Take benes and seeþ hem and grynde hem in a morter [1] and drawe hem
# 38: up [2] with gode broth an do Oynouns in the broth grete mynced [3] an
# 39: do þerto and colour it with Safroun and serve it forth.
# 40:
#
# *** Recipe 12 (lines 46-51) ***
# 46: FOR TO MAKE GREWEL FORCED [1]. III.
# 47:
# 48: Take grewel and do to the fyre with gode flessh and seeþ it wel. take
# 49: the lire [2] of Pork and grynd it smal [3] and drawe the grewel
# 50: thurgh a Straynour [4] and colour it wiþ Safroun and serue [5] forth.
# 51:
#
# *** Recipe 13 (lines 59-65) ***
# 59: CABOCHES [1] IN POTAGE. IIII.
# 60:
# 61:
# 62: Take Caboches and quarter hem and seeth hem in gode broth with
# 63: Oynouns y mynced and the whyte of Lekes y slyt and corue smale [2]
# 64: and do þer to safroun an salt and force it with powdour douce [3].
# 65:
#
# *** Recipe 14 (lines 71-78) ***
# 71: RAPES [1] IN POTAGE. V.
# 72:
# 73: Take rapus and make hem clene and waissh hem clene. quare hem [2].
# 74: parboile hem. take hem up. cast hem in a gode broth and seeþ hem.
# 75: mynce Oynouns and cast þerto Safroun and salt and messe it forth
# 76: with powdour douce. the wise [3] make of Pasturnakes [4] and
# 77: skyrwates. [5]
# 78:
#
# *** Recipe 15 (lines 88-94) ***
# 88: EOWTES [1] OF FLESSH. VI.
# 89:
# 90: Take Borage, cool [2]. langdebef [3]. persel [4]. betes. orage [5].
# 91: auance [6]. violet [7]. saueray [8]. and fenkel [9]. and whane þey
# 92: buth sode; presse hem wel smale. cast hem in gode broth an seeþ hem.
# 93: and serue hem forth.
# 94:
#
# *** Recipe 16 (lines 109-115) ***
# 109: HEBOLACE [1]. VII.
# 110:
# 111:
# 112: Take Oynouns and erbes and hewe hem small and do þes to gode broth.
# 113: and aray [2] it as þou didest caboches. I
#
#
# *** Recipe 17 (lines 5-23) ***
# 5: EOWTES [1] OF FLESSH. VI.
# 6:
# 7: Take Borage, cool [2]. langdebef [3]. persel [4]. betes. orage [5].
# 8: auance [6]. violet [7]. saueray [8]. and fenkel [9]. and whane þey
# 9: buth sode; presse hem wel smale. cast hem in gode broth an seeþ hem.
# 10: and serue hem forth.
# 11:
# 12: [1] Eowtes. _Lowtes_, No. 88, where, in the process, it is _Rowtes_.
# 13:     Quære the meaning, as Roots does not apply to the matter of the
# 14:     Recipe. In No. 73 it is written _owtes_.
# 15: [2] Cole, or colewort.
# 16: [3] Langdebef. Bugloss, buglossum sylvestre. These names all arise
# 17:     from a similitude to an ox's tongue. V. Ms. Ed. No. 43.
# 18: [4] Persel. Parsley.
# 19: [5] orage. Orach, _Atriplex_. Miller, Gard. Dict.
# 20: [6] auance. Fortè Avens. V. Avens, in Gloss.
# 21: [7] The leaves probably, and not the flower.
# 22: [8] Savory.
# 23: [9] Fenkel. Fennil.
#
# *** Recipe 18 (lines 26-42) ***
# 26: HEBOLACE [1]. VII.
# 27:
# 28:
# 29: Take Oynouns and erbes and hewe hem small and do þes to gode broth.
# 30: and aray [2] it as þou didest caboches. If þey be in fyssh day. make
# 31: [3] on the same maner [4] with water and oyle. and if it be not in
# 32: Lent alye [5] it with zolkes of Eyren [6]. and dresse it forth and
# 33: cast þer to powdour douce.
# 34:
# 35: [1] Hebolace. Contents, Hebolas; for _Herbolas_, from the herbs used;
# 36:     or, if the first letter be omitted (see the Contents), _Chebolas_,
# 37:     from the Chibols employed.
# 38: [2] aray. Dress, set it out.
# 39: [3] make. Dress. Vide Gloss.
# 40: [4] maner. manner.
# 41: [5] alye. Mix. V. Gloss.
# 42: [6] Eyren. Eggs. V. Gloss.
#
# *** Recipe 19 (lines 45-53) ***
# 45: GOURDES IN POTAGE. VIII.
# 46:
# 47: Take young Gowrdes pare hem and kerue [1] hem on pecys. cast hem in
# 48: gode broth, and do þer to a gode pertye [2] of Oynouns mynced. take
# 49: Pork soden. grynd it and alye it þer with and wiþ zolkes of ayrenn.
# 50: do þer to safroun and salt, and messe it forth with powdour douce.
# 51:
# 52: [1] kerve. Cut.
# 53: [2] partye. Party, i.e. quantity.
#
# *** Recipe 20 (lines 56-64) ***
# 56: RYSE [1] OF FLESH. IX.
# 57:
# 58: Take Ryse and waishe hem clene. and do hem in erthen pot with gode
# 59:
# 60: broth and lat hem seeþ wel. afterward take Almaund mylke [2] and do
# 61: þer to. and colour it wiþ safroun an salt, an messe forth.
# 62:
# 63: [1] Ryse. Rice. V. Gloss.
# 64: [2] Almand mylke. V. Gloss.
#
# *** Recipe 21 (lines 67-75) ***
# 67: FUNGES [1]. X.
# 68:
# 69: Take Funges and pare hem clere and dyce hem [2]. take leke and shred
# 70: hym small and do hym to seeþ in gode broth. colour it with safron and
# 71: do þer inne powdour fort [3].
# 72:
# 73: [1] Funges. Mushrooms.
# 74: [2] dyce hem. Cut them in squares. Vide _quare_ in Gloss.
# 75: [3] Powdour fort. Vide Preface.
#
# *** Recipe 22 (lines 78-89) ***
# 78: BURSEN [1]. XI.
# 79:
# 80: Take the whyte of Lekes. slype hem and shrede hem small. take
# 81: Noumbles [2] of swyne and boyle hem in broth and wyne. take hym up
# 82: and dresse hem and do the Leke in the broth. seeþ and do the Noumbles
# 83: þer to make a Lyour [3] of brode blode and vynegre and do þer to
# 84: Powdour fort seeþ Oynouns mynce hem and do þer to. the self wise make
# 85: of Pigges.
# 86:
# 87: [1] Bursen. Qu. the etymon.
# 88: [2] Noumbles. Entrails. V. Gloss.
# 89: [3] Lyo', Lyour. A mixture. Vide _alye_ in Gloss.
#
# *** Recipe 23 (lines 92-103) ***
# 92: CORAT [1]. XII.
# 93:
# 94: Take the Noumbles of Calf. Swyne. or of Shepe. parboile hem and
# 95: skerne hem to dyce [2] cast hem in gode broth and do þer to erbes.
# 96: grynde chyballes [3]. smale y hewe. seeþ it tendre and lye it with
# 97: zolkes of eyrenn. do þer to verious [4] safroun powdour douce and
# 98: salt, and serue it forth.
# 99:
# 100: [1] Corat. Qu.
# 101: [2] kerve hem to dyce. V. _quare_ in Gloss.
# 102: [3] Chyballes. Chibols, young onions. V. Gloss.
# 103: [4] verious. Verjuice.
#
# *** Recipe 24 (lines 106-117) ***
# 106: NOUMBLES. XIII.
# 107:
# 108: Take noumbles of Deer oþer [1] of oþer beest parboile hem kerf hem to
# 109: dyce. take the self broth or better. take brede and grynde with the
# 110: broth. and temper it [2] up with a gode quantite of vyneger and wyne.
# 111: take the oynouns and parboyle hem. and mynce hem smale and do þer to.
# 112: colour it with blode and do þer to powdour fort and salt and boyle it
# 113: wele and serue it fort [3].
# 114:
# 115: [1] oþer. Other, i.e. or.
# 116: [2] temper it. Temper it, i. e. mix it.
# 117: [3] fort. Miswritten for _forth_. So again No. 31. 127.
#
# *** Recipe 25 (lines 120-126) ***
# 120: ROO [1] BROTH. XIIII.
# 121:
# 122: Take the lire of the Deer oþer of the Roo parboile it on smale peces.
# 123: seeþ it wel half in water and half in wyne. take brede and bray it
# 124: wiþ the self broth and drawe blode þer to and lat it seet
#
#
# *** Recipe 26 (lines 0-2) ***
# 0: nde chyballes [3]. smale y hewe. seeþ it tendre and lye it with
# 1: zolkes of eyrenn. do þer to verious [4] safroun powdour douce and
# 2: salt, and serue it forth.
#
# *** Recipe 27 (lines 10-17) ***
# 10: NOUMBLES. XIII.
# 11:
# 12: Take noumbles of Deer oþer [1] of oþer beest parboile hem kerf hem to
# 13: dyce. take the self broth or better. take brede and grynde with the
# 14: broth. and temper it [2] up with a gode quantite of vyneger and wyne.
# 15: take the oynouns and parboyle hem. and mynce hem smale and do þer to.
# 16: colour it with blode and do þer to powdour fort and salt and boyle it
# 17: wele and serue it fort [3].
#
# *** Recipe 28 (lines 24-30) ***
# 24: ROO [1] BROTH. XIIII.
# 25:
# 26: Take the lire of the Deer oþer of the Roo parboile it on smale peces.
# 27: seeþ it wel half in water and half in wyne. take brede and bray it
# 28: wiþ the self broth and drawe blode þer to and lat it seeth to gedre
# 29: with powdour fort of gynger oþer of canell [2]. and macys [3]. with a
# 30: grete porcioun of vineger with Raysouns of Coraunte [4].
#
# *** Recipe 29 (lines 38-42) ***
# 38: TREDURE [1]. XV.
# 39:
# 40: Take Brede and grate it. make a lyre [2] of rawe ayrenn and do þerto
# 41: Safroun and powdour douce. and lye it up [3] with gode broth. and
# 42: make it as a Cawdel. and do þerto a lytel verious.
#
# *** Recipe 30 (lines 50-55) ***
# 50: MONCHELET [1]. XVI.
# 51:
# 52: Take Veel oþer Moton and smite it to gobettes seeþ it in gode broth.
# 53: cast þerto erbes yhewe [2] gode wyne. and a quantite of Oynouns
# 54: mynced. Powdour fort and Safroun. and alye it with ayren and verious.
# 55: but lat not seeþ after.
#
# *** Recipe 31 (lines 61-68) ***
# 61: BUKKENADE [1]. XVII.
# 62:
# 63: Take Hennes [2] oþer Conynges [3] oþer Veel oþer oþer Flessh an hewe
# 64: hem to gobettes waische it and hit well [4]. grynde Almandes
# 65: unblaunched. and drawe hem up with þe broth cast þer inne raysons of
# 66: Corance. sugur. Powdour gyngur erbes ystewed in grees [5]. Oynouns
# 67: and Salt. If it is to to [6] thynne. alye it up with flour of ryse
# 68: oþer with oþer thyng and colour it with Safroun.
#
# *** Recipe 32 (lines 81-87) ***
# 81: CONNATES [1]. XVIII.
# 82:
# 83: Take Connes and pare hem. pyke out the best and do hem in a pot of
# 84: erthe. do þerto whyte grece þat he stewe þer inne. and lye hem up
# 85: with hony clarified and with rawe zolkes [2] and with a lytell
# 86: almaund mylke and do þerinne powdour fort and Safron. and loke þat it
# 87: be yleesshed [3],
#
# *** Recipe 33 (lines 95-100) ***
# 95: DREPEE [1]. XIX.
# 96:
# 97: Take blanched Almandes grynde hem and temper hem up with gode broth
# 98: take Oynouns a grete quantite parboyle hem and frye hem and do þerto.
# 99: take smale bryddes [2] parboyle hem and do þerto Pellydore [3] and
# 100: salt. and a lytel grece.
#
# *** Recipe 34 (lines 107-117) ***
# 107: Mawmenee [1]. XX.
# 108:
# 109: Take a pottel of wyne greke. and ii. pounde of sugur take and
# 110: clarifye the sugur with a qantite of wyne an drawe it thurgh a
# 111: straynour in to a pot of erthe take flour of Canell [2]. and medle [3]
# 112: with sum of the wyne an cast to gydre. take pynes [4] with Dates and
# 113: frye hem a litell in grece oþer in oyle and cast hem to gydre. take
# 114: clowes [5] an flour of canel hool [6] and cast þerto. take powdour
# 115: gyngur. cane
#
#
# *** Recipe 35 (lines 0-8) ***
# 0:  loke þat it
# 1: be yleesshed [3],
# 2:
# 3: [1] Connat seems to be a kind of marmalade of connes, or quinces,
# 4:     from Fr. _Coing_. Chaucer, v. Coines. Written quinces No. 30.
# 5: [2] Yolkes, i. e. of Eggs.
# 6: [3] yleesshed. V. Gloss.
# 7:
# 8:
#
# *** Recipe 36 (lines 9-21) ***
# 9: DREPEE [1]. XIX.
# 10:
# 11: Take blanched Almandes grynde hem and temper hem up with gode broth
# 12: take Oynouns a grete quantite parboyle hem and frye hem and do þerto.
# 13: take smale bryddes [2] parboyle hem and do þerto Pellydore [3] and
# 14: salt. and a lytel grece.
# 15:
# 16: [1] Drepee. Qu.
# 17: [2] bryddes. Birds. _Per metathesin; v. R. in Indice_.
# 18: [3] Pellydore. Perhaps _pellitory_. _Peletour_, 104.
# 19:
# 20:
# 21: Mawmenee [1]. XX.
#
# *** Recipe 37 (lines 22-46) ***
# 22:
# 23: Take a pottel of wyne greke. and ii. pounde of sugur take and
# 24: clarifye the sugur with a qantite of wyne an drawe it thurgh a
# 25: straynour in to a pot of erthe take flour of Canell [2]. and medle [3]
# 26: with sum of the wyne an cast to gydre. take pynes [4] with Dates and
# 27: frye hem a litell in grece oþer in oyle and cast hem to gydre. take
# 28: clowes [5] an flour of canel hool [6] and cast þerto. take powdour
# 29: gyngur. canel. clower, colour it with saundres a lytel yf hit be nede
# 30: cast salt þerto. and lat it seeþ; warly [7] with a slowe fyre and not
# 31: to thyk [8], take brawn [9] of Capouns yteysed [10]. oþer of
# 32: Fesauntes teysed small and cast þerto.
# 33:
# 34: [1] Vide No. 194, where it is called _Mawmenny_.
# 35: [2] Flour of Canell. Powder of Cinamon.
# 36: [3] medle. Mix.
# 37: [4] pynes. A nut, or fruit. Vide Gloss.
# 38: [5] clowes. Cloves.
# 39: [6] hool. Whole. How can it be the flour, or powder, if whole? Quære,
# 40:     _flower_ of cand for _mace_.
# 41: [7] warly. Warily, gently.
# 42: [8] not to thyk. So as to be too thick; or perhaps, _not to thicken_.
# 43: [9] brawn. Fleshy part. Few Capons are cut now except about Darking
# 44:     in Surry; they have been excluded by the turkey, a more magnificent,
# 45:     but perhaps not a better fowl.
# 46:
#
# *** Recipe 38 (lines 47-65) ***
# 47: [10] yteysed, or _teysed_, as afterwards. Pulled in pieces by the
# 48:      fingers, called _teezing_ No. 36. This is done now with flesh of
# 49:      turkeys, and thought better than mincing. Vide Junius, voce _Tease_.
# 50:
# 51:
# 52: EGURDOUCE [1]. XXI.
# 53:
# 54: Take Conynges or Kydde and smyte hem on pecys rawe. and frye hem in
# 55: white grece. take raysouns of Coraunce and fry hem take oynouns
# 56: parboile hem and hewe hem small and fry hem. take rede wyne suger
# 57: with powdour of peper. of gynger of canel. salt. and cast þerto. and
# 58: lat it seeþ with a gode quantite of white grece an serue it forth.
# 59:
# 60: [1] Egurdouce. The term expresses _piccante dolce_, a mixture of sour
# 61:     and sweet; but there is nothing of the former in the composition.
# 62:     Vide Gloss.
# 63:
# 64:
# 65: CAPOUNS IN COUNCYS [1]. XXII.
#
# *** Recipe 39 (lines 66-80) ***
# 66:
# 67: Take Capons and rost hem right hoot þat þey be not half y nouhz and
# 68: hewe hem to gobettes and cast hem in a pot, do þerto clene broth,
# 69: seeþ hem þat þey be tendre. take brede and þe self broth and drawe it
# 70: up yferer [2], take strong Powdour and Safroun and Salt and cast þer
# 71: to. take ayrenn and seeþ hem harde. take out the zolkes and hewe the
# 72: whyte þerinne, take the Pot fro þe fyre and cast the whyte þerinne.
# 73: messe the disshes þerwith and lay the zolkes hool and flour it with
# 74: clowes.
# 75:
# 76: [1] Concys seems to be a kind of known sauce. V. Gloss.
# 77: [2] yfere. Together.
# 78:
# 79:
# 80: HARES [1] IN TALBOTES [2]. XXIII.
#
# *** Recipe 40 (lines 81-96) ***
# 81:
# 82: Take Hares and hewe hem to gobettes and seeþ hem with þe blode
# 83: unwaisshed in broth. and whan þey buth y nowh: cast hem in colde
# 84: water. pyke and waisshe hem clene. cole [3] the broth and drawe it
# 85: thurgh a straynour. take oþer blode and cast in boylyng water seeþ it
# 86: and drawe it thurgh a straynour. take Almaundes unblaunched. waisshe
# 87: hem and grynde hem and temper it up with the self broth. cast al in a
# 88: pot. tak oynouns and parboile hem smyte hem small and cast hem in to
# 89: þis Pot. cast þerinne Powdour fort. vynegur an salt.
# 90:
# 91: [1] Haares, Contents. So again, No. 24.
# 92: [2] Talbotes. Ms. Ed. No. 9, _Talbotays_.
# 93: [3] Cole. Cool.
# 94:
# 95:
# 96: HARES IN PAPDELE [1]. XXIIII.
#
# *** Recipe 41 (lines 97-105) ***
# 97:
# 98: Take Hares parboile hem in gode broth. cole the broth and waisshe the
# 99: fleyssh. cast azeyn [2] to gydre. take obleys [3] oþer wafrouns [4]
# 100: in stede of lozeyns [5]. and cowche [6] in dysshes. take powdour
# 101: douce and lay on salt the broth and lay onoward [7] an messe forth.
# 102:
# 103: [1] Papdele.

# %%
import yaml

# Load recipes from recipes.json
with open("recipes.json") as f:
    recipes = json.load(f)

# For each recipe, extract the data with GPT-4
SYSTEM_MESSAGE = """
Output the title of the recipe, the ingredients, and the instructions.

Format your response as valid YAML, e.g.

title: "Recipe Title"
ingredients:
    "Ingredient 1": "Ingredient 1 amount"
    "Ingredient 2": "Ingredient 2 amount"
instructions:
- "Instruction 1"
- "Instruction 2"
...

Do not infer any information that is not present in the text. Just include "unknown" if you cannot find the information.

If you are unable to convert this into a recipe, output "FAIL".
""".strip()

recipe_resps = instruct_chat_model_batched(
    SYSTEM_MESSAGE,
    [recipe[0] for recipe in recipes],
    model="gpt-4"
)

# Print the responses
for i in range(len(recipe_resps)):
    print("Recipe {}:".format(i+1))
    print(recipe_resps[i]["choices"][0]["message"]["content"])
    print()
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]
# 100%|██████████| 41/41 [00:01<00:00, 22.68it/s]
# Recipe 1:
# FAIL
#
# Recipe 2:
# FAIL
#
# Recipe 3:
# title: "Unknown"
# ingredients:
#     "cheese": "unknown amount"
#     "flesh of capons or hens": "unknown amount"
#     "milk of almonds": "unknown amount"
#     "broth of fresh beef or fresh flesh": "unknown amount"
#     "flour of rye": "unknown amount"
#     "gastbon or amydon": "unknown amount"
#     "yolk of eggs": "unknown amount"
#     "saffron": "for coloring"
#     "cloves of gilofre": "unknown amount"
#     "powder of galyugale": "unknown amount"
#
# instructions:
# - "Take the cheese and flesh of capons, or of hens and chop small and grind small in a mortar."
# - "Take milk of almonds with the broth of fresh beef. or fresh flesh, and put the flesh in the milk or in the broth and set them to the fire."
# - "Mix them with flour of rye, or gastbon, or amydon as much as you want."
# - "Add yolks of eggs and saffron to make it yellow."
# - "When it is dressed in dishes as you desire, stick above cloves of gilofre."
# - "Sprinkle powder of galyugale above, and serve it forth."
#
# Recipe 4:
# FAIL
#
# Recipe 5:
# FAIL
#
# Recipe 6:
# FAIL
#
# Recipe 7:
# FAIL
#
# Recipe 8:
# FAIL
#
# Recipe 9:
# FAIL
#
# Recipe 10:
# title: "GRONDEN BENES"
# ingredients:
#     "benes": "unknown"
#     "good broth": "unknown"
#     "Bacon": "unknown"
# instructions:
# - "Take benes and dry them in an Ovene and hull them well."
# - "Wayshe them clean and do them to seethe in good broth."
# - "Ete them with Bacon."
#
# Recipe 11:
# title: "FOR TO MAKE DRAWEN BENES"
# ingredients:
#     "benes": "unknown amount"
#     "good broth": "unknown amount"
#     "Onions": "unknown amount, great minced"
#     "Saffron": "unknown amount, for color"
# instructions:
# - "Take benes and seeþ hem and grynde hem in a morter."
# - "Drawe hem up with good broth."
# - "Put great minced onions in the broth."
# - "Color it with Saffron."
# - "Serve it forth."
#
# Recipe 12:
# title: "TO MAKE GREWEL FORCED"
# ingredients:
#     "Grewel": "unknown"
#     "Good flesh": "unknown"
#     "Lire of Pork": "unknown"
#     "Safroun": "unknown"
# instructions:
# - "Take grewel and do to the fyre with gode flessh and seeþ it wel."
# - "Take the lire of Pork and grynd it smal and drawe the grewel thurgh a Straynour and colour it wiþ Safroun and serue forth."
#
# Recipe 13:
# title: "Caboches In Potage"
# ingredients:
#     "Caboches": "unknown"
#     "Good broth": "unknown"
#     "Oynouns": "unknown"
#     "The white of Lekes": "unknown"
#     "Safroun": "unknown"
#     "Salt": "unknown"
#     "Powdour douce": "unknown"
# instructions:
# - "Take Caboches and quarter them."
# - "Seeth them in good broth."
# - "Add minced Oynouns and the white of Lekes, slit and cored small."
# - "Add Safroun and Salt."
# - "Force it with powdour douce."
#
# Recipe 14:
# title: "Rapes In Potage"
# ingredients:
#     "Rapus": "unknown"
#     "Good broth": "unknown"
#     "Onions": "unknown"
#     "Saffron": "unknown"
#     "Salt": "unknown"
#     "Powder douce": "unknown"
#     "Pasturnakes": "unknown"
#     "Skyrwates": "unknown"
# instructions:
# - "Take rapus and make them clean and wash them clean."
# - "Quarter them and parboil them."
# - "Take them up, cast them in a good broth and seethe them."
# - "Mince Onions and cast to Saffron and salt."
# - "Serve it with powder douce."
# - "The wise make of Pasturnakes and skyrwates."
#
# Recipe 15:
# title: "EOWTES OF FLESSH"
# ingredients:
#     "Borage": "unknown"
#     "cool [2]": "unknown"
#     "langdebef [3]": "unknown"
#     "persel [4]": "unknown"
#     "betes": "unknown"
#     "orage [5]": "unknown"
#     "auance [6]": "unknown"
#     "violet [7]": "unknown"
#     "saueray [8]": "unknown"
#     "fenkel [9]": "unknown"
#     "gode broth": "unknown"
# instructions:
# - "Take Borage, cool, langdebef, persel, betes, orage, auance, violet, saueray, and fenkel."
# - "Once they are sode, press them well small."
# - "Cast them in gode broth and seeþ them."
# - "Serve them forth."
#
# Recipe 16:
# title: "HEBOLACE"
# ingredients:
#     "Oynouns": "unknown"
#     "erbes": "unknown"
#     "gode broth": "unknown"
# instructions:
# - "Take Oynouns and erbes and hewe hem small"
# - "Add to gode broth"
# - "Aray it as þou didest caboches."
#
# Recipe 17:
# title: "EOWTES OF FLESSH"
# ingredients:
#     "Borage": "unknown amount"
#     "cool(Colewort)": "unknown amount"
#     "langdebef(Bugloss)": "unknown amount"
#     "persel(Parsley)": "unknown amount"
#     "betes": "unknown amount"
#     "orage(Orach)": "unknown amount"
#     "auance(Avens)": "unknown amount"
#     "violet(unknown part)": "unknown amount"
#     "saueray(Savory)": "unknown amount"
#     "fenkel(Fennel)": "unknown amount"
#     "gode broth": "unknown amount"
# instructions:
# - "Take Borage, Colewort, Bugloss, Parsley, Betes, Orach, Avens, Violet, Savory, and Fennel."
# - "Once they are boiled, press them well small."
# - "Cast them in a good broth and seethe them."
# - "Serve them forth."
#
# Recipe 18:
# title: "HEBOLACE"
# ingredients:
#   "Oynouns": "unknown"
#   "erbes": "unknown"
#   "gode broth": "unknown"
#   "water": "unknown"
#   "oyle": "unknown"
#   "zolkes of Eyren": "unknown"
#   "powdour douce": "unknown"
# instructions:
# - "Take Oynouns and erbes and hewe hem small and do þes to gode broth."
# - "aray it as thou didest caboches."
# - "If they be in fyssh day, make on the same maner with water and oyle."
# - "and if it be not in Lent alye it with zolkes of Eyren."
# - "and dresse it forth and cast ther to powdour douce."
#
# Recipe 19:
# title: "GOURDES IN POTAGE"
# ingredients:
#     "young Gowrdes": "unknown"
#     "gode broth": "unknown"
#     "Oynouns": "a gode pertye [quantity]"
#     "Pork": "soden [cooked]"
#     "zolkes of ayrenn": "unknown"
#     "safroun": "unknown"
#     "salt": "unknown"
#     "powdour douce": "unknown"
# instructions:
# - "Take young Gowrdes pare hem and kerue [cut] hem on pecys."
# - "cast hem in gode broth, and do þer to a gode pertye of Oynouns mynced."
# - "take Pork soden. grynd it and alye it þer with and wiþ zolkes of ayrenn."
# - "do þer to safroun and salt, and messe it forth with powdour douce."
#
# Recipe 20:
# title: "Ryse of Flesh"
# ingredients:
#     "Ryse (Rice)": "unknown amount"
#     "Gode broth": "unknown amount"
#     "Almaund mylke (Almond milk)": "unknown amount"
#     "Safroun (Saffron)": "unknown amount"
#     "Salt": "unknown amount"
# instructions:
# - "Take Ryse and waishe hem clene. and do hem in erthen pot with gode broth and lat hem seeþ wel."
# - "Afterward take Almaund mylke and do þer to."
# - "Colour it wiþ safroun an salt, an messe forth."
#
# Recipe 21:
# title: "Funges (Mushrooms)"
# ingredients:
#     "Funges (Mushrooms)": "unknown amount"
#     "Leke": "unknown amount"
#     "Good broth": "unknown amount"
#     "Saffron for color": "unknown amount"
#     "Powdour fort": "unknown amount"
# instructions:
# - "Take Funges (Mushrooms) and pare them clear and dice them"
# - "Take leke and shred hm small and do him to seeþ in good broth"
# - "Colour it with saffron"
# - "Add powdour fort"
#
# Recipe 22:
# title: "BURSEN"
# ingredients:
#     "whyte of Lekes": "unknown"
#     "Noumbles of swyne": "unknown"
#     "broth": "unknown"
#     "wyne": "unknown"
#     "brode blode": "unknown"
#     "vynegre": "unknown"
#     "Powdour fort": "unknown"
#     "Oynouns": "unknown"
#     "Pigges": "unknown"
# instructions:
# - "Take the whyte of Lekes. slype hem and shrede hem small."
# - "Take Noumbles of swyne and boyle hem in broth and wyne. Take hym up and dresse hem and do the Leke in the broth."
# - "Seeþ and do the Noumbles ther to make a Lyour of brode blode and vynegre and do ther to."
# - "Powdour fort seeþ Oynouns mynce hem and do ther to."
# - "The self wise make of Pigges."
#
# Recipe 23:
# title: "Corat"
# ingredients:
#     "Noumbles of Calf, Swyne, or of Shepe": "unknown"
#     "gode broth": "unknown"
#     "erbes": "unknown"
#     "chyballes (Chibols, young onions)": "unknown"
#     "zolkes of eyrenn": "unknown"
#     "verious (Verjuice)": "unknown"
#     "safroun powdour douce": "unknown"
#     "salt": "unknown"
# instructions:
# - "Take the Noumbles of Calf, Swyne, or of Shepe, parboile hem and skerne hem to dyce"
# - "Cast hem in gode broth and do þer to erbes"
# - "Grynde chyballes (young onions), smale y hewe, seeþ it tendre and lye it with zolkes of eyrenn"
# - "Do þer to verious (Verjuice), safroun powdour douce and salt"
# - "Serve it forth."
#
# Recipe 24:
# title: "NOUMBLES. XIII."
# ingredients:
#     "Noumbles of Deer or other beast": "unknown quantity"
#     "Self broth or better": "unknown quantity"
#     "Bread": "unknown quantity"
#     "Vinegar": "a good quantity"
#     "Wine": "unknown quantity"
#     "Onions": "unknown quantity"
#     "Blood": "for colouring"
#     "Powdour fort": "unknown quantity"
#     "Salt": "to taste"
# instructions:
# - "Parboil the noumbles of Deer or other beast and cut them into dice."
# - "Take the self broth or better."
# - "Grind the bread with the broth and temper it up with a good quantity of vinegar and wine."
# - "Parboil the onions and mince them small and add to the mixture."
# - "Colour it with blood and add powdour fort and salt."
# - "Boil it well and serve it forth."
#
# Recipe 25:
# title: "ROO [1] BROTH. XIIII."
# ingredients:
#     "lire of the Deer or of the Roo": "unknown"
#     "water": "half the volume of the soup"
#     "wyne": "half the volume of the soup"
#     "brede": "unknown"
#     "blode": "unknown"
# instructions:
# - "Take the lire of the Deer or of the Roo and parboil it in small pieces"
# - "Simmer it well half in water and half in wyne"
# - "Take brede and bray it with the self broth"
# - "Draw blode to the broth mixture and let it simmer"
#
# Recipe 26:
# title: "Nde Chyballes"
# ingredients:
#     "Smale y hewe": "unknown"
#     "Zolkes of eyrenn": "unknown"
#     "Verious": "unknown"
#     "Safroun powdour douce": "unknown"
#     "Salt": "to taste"
# instructions:
# - "Seeþ smale y hewe until it is tender and ly it with zolkes of eyrenn"
# - "Add verious, safroun powdour douce, and salt"
# - "Serve it forth."
#
# Recipe 27:
# title: "NOUMBLES"
# ingredients:
#     "Noumbles of Deer or other meat": "unknown amount"
#     "Self broth or better": "unknown amount"
#     "Bread": "unknown amount"
#     "Vinegar": "a good quantity"
#     "Wine": "unknown amount"
#     "Onions": "unknown amount"
#     "Blood": "unknown amount"
#     "Powder fort": "unknown amount"
#     "Salt": "unknown amount"
# instructions:
# - "Parboil the noumbles of Deer or other meat and cut them into dice."
# - "Take the broth, grind the bread with it and temper it with a good quantity of vinegar and some wine."
# - "Parboil the onions, mince them small and add to the broth."
# - "Colour it with blood, and add powder fort and salt."
# - "Boil it well and serve."
#
# Recipe 28:
# title: "Roo Broth"
# ingredients:
#   "Deer or Roo liver": "unknown"
#   "Water": "half of the required liquid"
#   "Wine": "half of the required liquid"
#   "Bread": "unknown"
#   "Self broth": "unknown"
#   "Blood": "unknown"
#   "Powder fort of Ginger or Cinnamon": "unknown"
#   "Mace": "unknown"
#   "Vinegar": "a large portion"
#   "Raisins of Coraunte": "unknown"
# instructions:
# - "Take the liver of the Deer or the Roo, parboil it in small pieces."
# - "Seethe it well half in water and half in wine."
# - "Take bread and bray it with the self broth and draw blood to it and let it seethe together."
# - "Add powder fort of ginger or cinnamon, and mace, with a large portion of vinegar with raisins of Coraunte."
#
# Recipe 29:
# title: "TREDURE [1]. XV."
# ingredients:
#     "Brede": "unknown"
#     "rawe ayrenn": "unknown"
#     "Safroun": "unknown"
#     "powdour douce": "unknown"
#     "gode broth": "unknown"
#     "verious": "a lytel"
# instructions:
# - "Take Brede and grate it."
# - "Make a lyre [2] of rawe ayrenn and do þerto Safroun and powdour douce."
# - "Lye it up [3] with gode broth."
# - "Make it as a Cawdel."
# - "do þerto a lytel verious."
#
# Recipe 30:
# title: "Monchelet"
# ingredients:
#     "Veel or Moton": "unknown"
#     "Good Broth": "enough to cover the meat"
#     "Herbs": "unknown"
#     "Good Wine": "unknown"
#     "Onions": "a significant amount, minced"
#     "Powdour fort": "unknown"
#     "Saffron": "unknown"
#     "Eggs": "unknown"
#     "Verjuice": "unknown"
# instructions:
# - "Cut the veel or moton into gobbets"
# - "Cook it in good broth"
# - "Add minced herbs, a significant amount of minced onions, a Powdour fort, saffron, good wine"
# - "Combine it with eggs and verjuice"
# - "Do not allow it to cook further after this step."
#
# Recipe 31:
# title: "BUKKENADE"
# ingredients:
#   "Hennes, Conynges, Veel or other Flessh": "unknown amount"
#   "Almandes unblaunched": "unknown amount"
#   "broth": "unknown amount"
#   "raysons of Corance": "unknown amount"
#   "sugur": "unknown amount"
#   "Powdour gyngur": "unknown amount"
#   "erbes ystewed in grees": "unknown amount"
#   "Oynouns": "unknown amount"
#   "Salt": "unknown amount"
#   "flour of ryse": "unknown amount"
#   "Safroun": "unknown amount"
# instructions:
# - "Hewe the chosen meat into gobettes"
# - "Wash the meat"
# - "Grind the blanched almonds"
# - "Draw up the almonds with the broth"
# - "Cast in the raisins of corance, sugar, powdered ginger, stewed herbs in grease, onions, and salt"
# - "If it is too thin, combine it with rice flour or other thickening agent"
# - "Colour it with Safroun"
#
# Recipe 32:
# title: "Connates"
# ingredients:
#     "Connes": "unknown quantity"
#     "White grece": "unknown quantity"
#     "Honey, clarified": "unknown quantity"
#     "Raw yolks": "unknown quantity"
#     "Almond milk": "a little"
#     "Powdour fort": "unknown quantity"
#     "Saffron": "unknown quantity"
# instructions:
# - "Take Connes and pare them. Pick out the best and put them in a pot of earth."
# - "Add white grece so that it stews therein."
# - "Lie them up with clarified honey and with raw yolks."
# - "Add a little almond milk and put therein powdour fort and Saffron."
# - "Ensure that it be yleesshed."
#
# Recipe 33:
# title: "DREPEE [1]. XIX."
# ingredients:
#     "Blanched Almandes": "unknown amount"
#     "Gode broth": "unknown amount"
#     "Oynouns": "a grete quantite"
#     "Smale bryddes": "unknown amount"
#     "Pellydore": "unknown amount"
#     "Salt": "unknown amount"
#     "Grece": "a lytel"
# instructions:
# - "Take blanched Almandes grynde hem and temper hem up with gode broth"
# - "Take Oynouns a grete quantite parboyle hem and frye hem and do þerto."
# - "Take smale bryddes parboyle hem and do þerto Pellydore and salt. and a lytel grece."
#
# Recipe 34:
# title: "Mawmenee"
# ingredients:
#     "wyne greke": "a pottel"
#     "sugur": "ii. pounde"
#     "flour of Canell": "unknown amount"
#     "pynes": "unknown amount"
#     "Dates": "unknown amount"
#     "grece or oyle": "unknown amount"
#     "clowes": "unknown amount"
#     "powdour gyngur": "unknown amount"
#     "cane": "unknown amount"
# instructions:
# - "Take a pottel of wyne greke. and ii. pounde of sugur take and clarifye the sugur with a qantite of wyne an drawe it thurgh a straynour in to a pot of erthe."
# - "Take flour of Canell and medle with sum of the wyne an cast to gydre."
# - "Take pynes with Dates and frye hem a litell in grece oþer in oyle and cast hem to gydre."
# - "Take clowes an flour of canel hool and cast þerto."
# - "Take powdour gyngur, cane."
#
# Recipe 35:
# FAIL
#
# Recipe 36:
# title: "DREPEE"
# ingredients:
#     "Blanched Almandes": "unknown quantity"
#     "Good Broth": "unknown quantity"
#     "Oynouns": "a great quantity"
#     "Small bryddes (Birds)": "unknown quantity"
#     "Pellydore (Perhaps _pellitory_)": "unknown quantity"
#     "Salt": "unknown quantity"
#     "Grece": "a little"
# instructions:
# - "Take blanched Almandes grynde hem and temper hem up with gode broth"
# - "Take Oynouns a grete quantite parboyle hem and frye hem and do þerto."
# - "Take smale bryddes parboyle hem and do þerto Pellydore and salt. and a lytel grece."
#
# Recipe 37:
# title: "Unknown"
# ingredients:
#     "wyne greke": "a pottel"
#     "sugur": "ii. pounde"
#     "flour of Canell [Powder of Cinamon]": "unknown amount"
#     "pynes [A nut, or fruit]": "unknown amount"
#     "Dates": "unknown amount"
#     "grece oþer in oyle": "for frying"
#     "clowes [Cloves]": "unknown amount"
#     "powdour gyngur": "unknown amount"
#     "canel": "unknown amount"
#     "clower": "unknown amount"
#     "saundres": "a lytel"
#     "salt": "unknown amount"
#     "brawn [Fleshy part] of Capouns": "unknown amount"
#     "Fesauntes [presumably fasan, pheasant]": "unknown amount"
# instructions:
# - "Take a pottel of wyne greke. and ii. pounde of sugur take and clarifye the sugur with a qantite of wyne an drawe it thurgh a straynour in to a pot of erthe"
# - "Take flour of Canell [2]. and medle [mix] with sum of the wyne an cast to gydre."
# - "Take pynes [nuts] with Dates and frye hem a litell in grece oþer in oyle and cast hem to gydre."
# - "Take clowes [cloves] an flour of canel hool [whole] and cast þerto."
# - "Take powdour gyngur, canel, clower, colour it with saundres a lytel yf hit be nede"
# - "Cast salt þerto, and lat it seeþ warly [gently] with a slowe fyre and not to thyk [not to thicken]."
# - "Take brawn [fleshy part] of Capouns yteysed [unknown term] oþer [or] of Fesauntes [presumably fasan, pheasant] teysed small and cast þerto."
#
# Recipe 38:
# title: "EGURDOUCE"
# ingredients:
#     "Conynges or Kydde": "unknown"
#     "white grece": "unknown"
#     "raysouns of Coraunce": "unknown"
#     "oynouns": "unknown"
#     "rede wyne": "unknown"
#     "suger": "unknown"
#     "powdour of peper": "unknown"
#     "gynger": "unknown"
#     "canel": "unknown"
#     "salt": "unknown"
# instructions:
# - "Take Conynges or Kydde and smyte hem on pecys rawe. and frye hem in white grece."
# - "Take raysouns of Coraunce and fry hem."
# - "Take oynouns parboile hem and hewe hem small and fry hem."
# - "Take rede wyne suger with powdour of peper, of gynger of canel, salt, and cast þerto."
# - "Let it seeþ with a gode quantite of white grece and serue it forth."
#
# Recipe 39:
# title: "HARES IN TALBOTES"
# ingredients:
#   "Capon": "unknown"
#   "Clean Broth": "unknown"
#   "Bread": "unknown"
#   "Strong Powdour": "unknown"
#   "Saffron": "unknown"
#   "Salt": "unknown"
#   "Hard-boiled Eggs": "unknown"
#   "Cloves": "unknown"
# instructions:
# - "Take Capons and roast them right hot that they be not half enough and
#   hew them to gobettes and cast them in a pot, add clean broth"
# - "Boil them that they be tender."
# - "Take bread and the self broth and draw it up together"
# - "Add strong powder, saffron, and salt."
# - "Hard-boil eggs, take out the yolks and hew the white therein, remove the Pot from the fire and add the whites."
# - "Prepare the dishes with it and lay the yolks whole and flour it with cloves."
#
# Recipe 40:
# title: "HARES IN PAPDELE"
# ingredients:
#     "Hares": "unknown"
#     "Broth": "unknown"
#     "Blood": "unknown"
#     "Almaundes unblaunched": "unknown"
#     "Onions": "unknown"
#     "Powdour fort": "unknown"
#     "Vynegur": "unknown"
#     "Salt": "unknown"
# instructions:
# - "Take Hares and hewe hem to gobettes and seeþ hem with þe blode unwaisshed in broth."
# - "And whan þey buth y nowh: cast hem in colde water. pyke and waisshe hem clene."
# - "Cole [3] the broth and drawe it thurgh a straynour."
# - "Take oþer blode and cast in boylyng water seeþ it and drawe it thurgh a straynour."
# - "Take Almaundes unblaunched. waisshe hem and grynde hem and temper it up with the self broth."
# - "Cast al in a pot."
# - "Tak oynouns and parboile hem smyte hem small and cast hem in to þis Pot."
# - "Cast þerinne Powdour fort. vynegur an salt."
#
# Recipe 41:
# title: "Papdele"
# ingredients:
#     "Hares": "unknown"
#     "gode broth": "unknown"
#     "fleyssh": "unknown"
#     "obleys or wafrouns": "unknown"
#     "powdour douce": "unknown"
#     "salt": "unknown"
# instructions:
# - "Take Hares parboile hem in gode broth."
# - "Cole the broth and waisshe the fleyssh."
# - "Cast azeyn to gydre."
# - "Take obleys or wafrouns in stede of lozeyns, and cowche in dysshes."
# - "Take powdour douce and lay on salt the broth and lay onoward an messe forth."

# %%
# Extract the data from the responses
recipe_data = []
for i in range(len(recipe_resps)):
    # If the recipe failed, just add "FAIL"
    if recipe_resps[i]["choices"][0]["message"]["content"] == "FAIL":
        continue

    data = yaml.safe_load(recipe_resps[i]["choices"][0]["message"]["content"])
    recipe_data.append(data)

# Save recipes to JSON
with open("recipes_data.json", "w") as f:
    json.dump(recipe_data, f)

# %%
# Save recipes to JSON
with open("recipes_data.json") as f:
    recipe_data = json.load(f)

# For each recipe, extract the data with GPT-4
SYSTEM_MESSAGE = """
You will be given a YAML object representing a recipe. It will be written in an arbitrary language. Convert it to modern English, while keeping as much original meaning and inflection as possible. Keep the YAML structure exactly the same.
""".strip()

recipe_resps = instruct_chat_model_batched(
    SYSTEM_MESSAGE,
    [yaml.dump(recipe) for recipe in recipe_data[:10]],
    model="gpt-4"
)

# Print the responses
for i in range(len(recipe_resps)):
    print("Recipe {}:".format(i+1))
    print(recipe_resps[i]["choices"][0]["message"]["content"])
    print()
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 67432.54it/s]
# Recipe 1:
# ingredients:
#   fresh beef or meat broth: unknown amount
#   cheese: unknown amount
#   cloves of clove: unknown amount
#   chicken or hen meat: unknown amount
#   rye flour: unknown amount
#   gastbon or cornstarch: unknown amount
#   almond milk: unknown amount
#   galingale powder: unknown amount
#   saffron: for coloring
#   egg yolks: unknown amount
# instructions:
# - Take the cheese and meat from chickens or hens, chop them finely and grind them in
#   a mortar.
# - Take almond milk with the fresh beef or meat broth, and put the meat
#   in the milk or in the broth and bring them to the boil.
# - Mix them with rye flour, or gastbon, or cornstarch according to your preference.
# - Add egg yolks and saffron to give it a yellow color.
# - When it is served in dishes as you like, sprinkle some cloves on top.
# - Sprinkle galingale powder on top, and serve it.
# title: Unknown
#
# Recipe 2:
# ingredients:
#   Bacon: unknown
#   Beans: unknown
#   High-quality broth: unknown
# instructions:
# - Take beans and dry them in an oven and remove their outer layer well.
# - Wash them clean and allow them to simmer in high-quality broth.
# - Eat them with Bacon.
# title: GROUND BEANS
#
# Recipe 3:
# ingredients:
#   Onions: unknown quantity, finely chopped
#   Saffron: unknown quantity, for color
#   Beans: unknown quantity
#   Quality broth: unknown quantity
# instructions:
# - "Take beans, inspect them, and grind them with a mortar."
# - Mix them well with the quality broth.
# - Add the finely chopped onions into the broth.
# - Give it color with Saffron.
# - Serve the dish.
# title: HOW TO PREPARE MASHED BEANS
#
# Recipe 4:
# ingredients:
#   Quality meat: unknown
#   Gruel: unknown
#   Pork liver: unknown
#   Saffron: unknown
# instructions:
# - "Take gruel and put it on the fire with quality meat and cook it thoroughly."
# - "Take the pork liver and grind it finely and sift the gruel through a strainer and color it with Saffron and serve forth."
# title: TO MAKE FIGURATIVE GRUEL
#
# Recipe 5:
# ingredients:
#   Cabbages: unknown
#   High-quality broth: unknown
#   Onions: unknown
#   Sweet spice mix: unknown
#   Saffron: unknown
#   Salt: unknown
#   The white part of Leeks: unknown
# instructions:
# - Take Cabbages and quarter them.
# - Boil them in high-quality broth.
# - Add minced Onions and the white part of Leeks, slit and cored small.
# - Add Saffron and Salt.
# - Enhance it with sweet spice mix.
# title: Cabbage In Soup
#
# Recipe 6:
# ingredients:
#   Good broth: unknown
#   Onions: unknown
#   Parsnips: unknown
#   Sweet spice mix: unknown
#   Turnips: unknown
#   Saffron: unknown
#   Salt: unknown
#   Small wheat loaves: unknown
# instructions:
# - Take turnips, clean them and wash them thoroughly.
# - Quarter them and parboil them.
# - Lift them out, put them in a good broth and simmer them.
# - Chop Onions and add to Saffron and salt.
# - Serve it with a sweet spice mix.
# - Knowledgeable people add Parsnips and small wheat loaves.
# title: Turnips In Broth
#
# Recipe 7:
# ingredients:
#   Borage: unknown
#   aurice [6]: unknown
#   beets: unknown
#   cole [2]: unknown
#   fennel [9]: unknown
#   good broth: unknown
#   long beef [3]: unknown
#   orange [5]: unknown
#   parsley [4]: unknown
#   sorrel [8]: unknown
#   violet [7]: unknown
# instructions:
# - Take Borage, cole, long beef, parsley, beets, orange, aurice, violet, sorrel, and fennel.
# - Once they are boiled, crush them well small.
# - "Put them in good broth and simmer them."
# - Serve them forth.
# title: MEATS OF FLESH
#
# Recipe 8:
# ingredients:
#   Onions: unknown
#   Herbs: unknown
#   Good broth: unknown
# instructions:
# - Take onions and herbs and chop them finely
# - Add to good broth
# - "Arrange it as you would cabbages."
# title: Hebolace
#
# Recipe 9:
# ingredients:
#   Borage: unknown quantity
#   Avens: unknown quantity
#   Beets: unknown quantity
#   Colewort: unknown quantity
#   Fennel: unknown quantity
#   Good broth: unknown quantity
#   Bugloss: unknown quantity
#   Orach: unknown quantity
#   Parsley: unknown quantity
#   Savory: unknown quantity
#   Violet(unknown part): unknown quantity
# instructions:
# - Take Borage, Colewort, Bugloss, Parsley, Beets, Orach, Avens, Violet, Savory, and Fennel.
# - Once they have been boiled, mash them well.
# - Mix them in a good broth and simmer them.
# - Serve them forth.
# title: EOWTES OF FLESSH
#
# Recipe 10:
# ingredients:
#   Onions: unknown
#   Herbs: unknown
#   Good Broth: unknown
#   Oil: unknown
#   Sweet Powder: unknown
#   Water: unknown
#   Egg Yolks: unknown
# instructions:
# - "Take onions and herbs, chop them finely and add them to the good broth."
# - Arrange it as you would cabbages.
# - If it's a fish day, make it similarly using water and oil.
# - And if it's not during Lent, bind it together with egg yolks.
# - Then plate it and sprinkle over the sweet powder.
# title: HERBOLACE
